# %%
import warnings
import pandas as pd
from pathlib import Path

# %%
# File Path
school_metrics_data_to_load = Path("data/SPREE_SY2223_School_Metric_Scores.csv")

# Read shcool metrics into Pandas DataFrames
school_metrics_data = pd.read_csv(school_metrics_data_to_load)

# %%
school_metrics_data.head()
# Out:
#   accountability_year  school_id               school_name  report_type  \
# 0           2022-2023       1010  John Bartram High School  High School
# 1           2022-2023       1010  John Bartram High School  High School
# 2           2022-2023       1010  John Bartram High School  High School
# 3           2022-2023       1010  John Bartram High School  High School
# 4           2022-2023       1010  John Bartram High School  High School
#
#                                               metric  numerator  denominator  \
# 0                                     Admission Type        NaN          NaN
# 1  % of Students Attending Less Than 80% of Instr...      292.0        617.0
# 2  % of Students Attending 80-85% of Instructiona...       51.0        617.0
# 3  % of Students Attending 85-90% of Instructiona...       66.0        617.0
# 4  % of Students Attending at Least 90% of Instru...      208.0        617.0
#
#   metric_score score_previous    score_change         tier
# 0    Catchment   Neighborhood  Not Applicable          NaN
# 1         47.3            NaN             NaN          NaN
# 2          8.3            NaN             NaN          NaN
# 3         10.7            NaN             NaN          NaN
# 4         33.7           33.8            -0.1  Maintaining

# %%
school_metrics_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83980 entries, 0 to 83979
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   accountability_year  83980 non-null  object
#  1   school_id            83980 non-null  int64
#  2   school_name          83980 non-null  object
#  3   report_type          83980 non-null  object
#  4   metric               83980 non-null  object
#  5   numerator            20464 non-null  float64
#  6   denominator          17254 non-null  float64
#  7   metric_score         83980 non-null  object
#  8   score_previous       71701 non-null  object
#  9   score_change         71706 non-null  object
#  10  tier                 11507 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 7.0+ MB

# %%
# Calculate and print the number of schools
schools_count = school_metrics_data['school_id'].nunique()
print("Number of unique schools:",schools_count)

# List the unique school ids
unique_ids = school_metrics_data['school_id'].unique()
# print("Number of unique school IDs:",unique_ids)
# Out:
# Number of unique schools: 294

# %%
#Calculate and print the number of school names
school_name_count = school_metrics_data['school_name'].nunique()
print("Number of unique schools:",school_name_count)

# List the unique school names
unique_names = school_metrics_data['school_name'].unique()
# print("Number of unique school names:",unique_names)
# Out:
# Number of unique schools: 294

# %%
#Calculate and print the number of unique metrics
metrics_count=school_metrics_data['metric'].nunique()
print("Number of unique metrics:",metrics_count)

# List the unique metrics
unique_metrics = school_metrics_data['metric'].unique()
# unique_metrics
# Out:
# Number of unique metrics: 260

# %%
#Calculate and print the number of Report Types
report_types_count = school_metrics_data['report_type'].nunique()
print("Number of report types:",report_types_count)

# List the Report Types
unique_reports = school_metrics_data['report_type'].unique()
print("Report Types:", unique_reports)
# Out:
# Number of report types: 4
# Report Types: ['High School' 'Middle School' 'K-8 School' 'Elementary School']

# %%
# Identify duplicates based on 'school_id' and 'metric'
duplicates = school_metrics_data[school_metrics_data.duplicated(subset=['school_id', 'metric'], keep=False)]
duplicate_school_count = duplicates['school_name'].nunique()
print("Number of duplicate School IDs:", duplicate_school_count)

# List the Duplicate Schools
duplicate_schools = duplicates['school_name'].unique()
# print("Duplicate Schools:", duplicate_schools)
# Out:
# Number of duplicate School IDs: 29

# %%
# Create the 'High School' 'Middle School' 'K-8 School' 'Elementary School' dataframes
high_school_metrics_df = school_metrics_data.loc[school_metrics_data['report_type'] == 'High School']
middle_school_metrics_df = school_metrics_data.loc[school_metrics_data['report_type'] == 'Middle School']
ktoeight_school_metrics_df = school_metrics_data.loc[school_metrics_data['report_type'] == 'K-8 School']
elementary_school_metrics_df = school_metrics_data.loc[school_metrics_data['report_type'] == 'Elementary School']

# Check for duplicates
high_school_duplicates = high_school_metrics_df[high_school_metrics_df.duplicated(subset=['school_id', 'metric'], keep=False)]
duplicate_high_school_count = high_school_duplicates['school_name'].nunique()
middle_school_duplicates = middle_school_metrics_df[middle_school_metrics_df.duplicated(subset=['school_id', 'metric'], keep=False)]
duplicate_middle_school_count = middle_school_duplicates['school_name'].nunique()
ktoeight_school_duplicates = ktoeight_school_metrics_df[ktoeight_school_metrics_df.duplicated(subset=['school_id', 'metric'], keep=False)]
duplicate_ktoeight_school_count = ktoeight_school_duplicates['school_name'].nunique()
elementary_school_duplicates = elementary_school_metrics_df[elementary_school_metrics_df.duplicated(subset=['school_id', 'metric'], keep=False)]
duplicate_elementary_school_count = elementary_school_duplicates['school_name'].nunique()

print("Number of duplicate High Schools:", duplicate_high_school_count)
print('-' * 40)
print("Number of duplicate Middle Schools:", duplicate_middle_school_count)
print('-' * 40)
print("Number of duplicate K-8 Schools:", duplicate_ktoeight_school_count)
print('-' * 40)
print("Number of duplicate Elementary Schools:", duplicate_elementary_school_count)
# Out:
# Number of duplicate High Schools: 0
# ----------------------------------------
# Number of duplicate Middle Schools: 0
# ----------------------------------------
# Number of duplicate K-8 Schools: 0
# ----------------------------------------
# Number of duplicate Elementary Schools: 0

# %%
# Calculate the number of school names
high_school_count = high_school_metrics_df['school_name'].nunique()
middle_school_count = middle_school_metrics_df['school_name'].nunique()
ktoeight_school_count = ktoeight_school_metrics_df['school_name'].nunique()
elementary_school_count = elementary_school_metrics_df['school_name'].nunique()

# Print info for the dataframes 
print("Number of High Schools:", high_school_count)
high_school_metrics_df.info()
print('-' * 60)
print("Number of Middle Schools:", middle_school_count)
middle_school_metrics_df.info()
print('-' * 60)
print("Number of K-8 Schools:", ktoeight_school_count)
ktoeight_school_metrics_df.info()
print('-' * 60)
print("Number of Elementary Schools:", elementary_school_count)
elementary_school_metrics_df.info()
print('-' * 60)
all_schools = high_school_count + middle_school_count + ktoeight_school_count + elementary_school_count
print("Number of Schools:", all_schools)
# Out:
# Number of High Schools: 84
# <class 'pandas.core.frame.DataFrame'>
# Index: 21840 entries, 0 to 83719
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   accountability_year  21840 non-null  object
#  1   school_id            21840 non-null  int64
#  2   school_name          21840 non-null  object
#  3   report_type          21840 non-null  object
#  4   metric               21840 non-null  object
#  5   numerator            4719 non-null   float64
#  6   denominator          3879 non-null   float64
#  7   metric_score         21840 non-null  object
#  8   score_previous       18647 non-null  object
#  9   score_change         18648 non-null  object
#  10  tier                 1158 non-null   object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 2.0+ MB
# ------------------------------------------------------------
# Number of Middle Schools: 29
# <class 'pandas.core.frame.DataFrame'>
# Index: 7540 entries, 1300 to 77739
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   accountability_year  7540 non-null   object
#  1   school_id            7540 non-null   int64
#  2   school_name          7540 non-null   object
#  3   report_type          7540 non-null   object
#  4   metric               7540 non-null   object
#  5   numerator            1574 non-null   float64
#  6   denominator          1284 non-null   float64
#  7   metric_score         7540 non-null   object
#  8   score_previous       6437 non-null   object
#  9   score_change         6438 non-null   object
#  10  tier                 927 non-null    object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 706.9+ KB
# ------------------------------------------------------------
# Number of K-8 Schools: 154
# <class 'pandas.core.frame.DataFrame'>
# Index: 40040 entries, 1820 to 83979
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   accountability_year  40040 non-null  object
#  1   school_id            40040 non-null  int64
#  2   school_name          40040 non-null  object
#  3   report_type          40040 non-null  object
#  4   metric               40040 non-null  object
#  5   numerator            10476 non-null  float64
#  6   denominator          8956 non-null   float64
#  7   metric_score         40040 non-null  object
#  8   score_previous       34185 non-null  object
#  9   score_change         34188 non-null  object
#  10  tier                 7009 non-null   object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 3.7+ MB
# ------------------------------------------------------------
# Number of Elementary Schools: 56
# <class 'pandas.core.frame.DataFrame'>
# Index: 14560 entries, 2340 to 82939
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   accountability_year  14560 non-null  object
#  1   school_id            14560 non-null  int64
#  2   school_name          14560 non-null  object
#  3   report_type          14560 non-null  object
#  4   metric               14560 non-null  object
#  5   numerator            3695 non-null   float64
#  6   denominator          3135 non-null   float64
#  7   metric_score         14560 non-null  object
#  8   score_previous       12432 non-null  object
#  9   score_change         12432 non-null  object
#  10  tier                 2413 non-null   object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 1.3+ MB
# ------------------------------------------------------------
# Number of Schools: 323

# %%
high_school_metrics_df.head()
# Out:
#   accountability_year  school_id               school_name  report_type  \
# 0           2022-2023       1010  John Bartram High School  High School
# 1           2022-2023       1010  John Bartram High School  High School
# 2           2022-2023       1010  John Bartram High School  High School
# 3           2022-2023       1010  John Bartram High School  High School
# 4           2022-2023       1010  John Bartram High School  High School
#
#                                               metric  numerator  denominator  \
# 0                                     Admission Type        NaN          NaN
# 1  % of Students Attending Less Than 80% of Instr...      292.0        617.0
# 2  % of Students Attending 80-85% of Instructiona...       51.0        617.0
# 3  % of Students Attending 85-90% of Instructiona...       66.0        617.0
# 4  % of Students Attending at Least 90% of Instru...      208.0        617.0
#
#   metric_score score_previous    score_change         tier
# 0    Catchment   Neighborhood  Not Applicable          NaN
# 1         47.3            NaN             NaN          NaN
# 2          8.3            NaN             NaN          NaN
# 3         10.7            NaN             NaN          NaN
# 4         33.7           33.8            -0.1  Maintaining

# %%
# list all the high school metrics
hs_unique_metrics = high_school_metrics_df['metric'].unique()
hs_unique_metrics
# Out:
# array(['Admission Type',
#        '% of Students Attending Less Than 80% of Instructional Days',
#        '% of Students Attending 80-85% of Instructional Days',
#        '% of Students Attending 85-90% of Instructional Days',
#        '% of Students Attending at Least 90% of Instructional Days',
#        '% of Students Attending 90-95% of Instructional Days',
#        '% of Students Attending at Least 95% of Instructional Days',
#        'Number of Dropouts - Last School of Touch (Grades 7-12)',
#        '# of Students Served Over the Full Year', 'October 1 Enrollment',
#        '% of Students Who Are American Indian/Alaskan Native',
#        '% of Students Who Are Asian',
#        '% of Students Who Are Black/African American',
#        '% of Students Who Are Economically Disadvantaged',
#        '% of Students Who Are English Learners',
#        '% of Students Who Are Hispanic/Latino',
#        '% of Students Who Are Multiracial',
#        '% of Students Who Are Native Hawaiian/Alaskan Native',
#        '% of Students Who Are Special Education',
#        '% of Students Who Are White',
#        '% of Students Completing the FAFSA by End of 12th Grade',
#        'First-Fall Matriculation', 'Score Level,  All Students',
#        'Score Level,  American Indian/Alaskan Native',
#        'Score Level,  Asian', 'Score Level,  Black/African American',
#        'Score Level,  Economically Disadvantaged',
#        'Score Level,  English Learners', 'Score Level,  Hispanic/Latino',
#        'Score Level,  Multiracial',
#        'Score Level,  Native Hawaiian/Pacific Islander',
#        'Score Level,  Special Education', 'Score Level,  White',
#        'Four-Year Cohort Graduation Rate',
#        'Four-Year Cohort Graduation Rate, American Indian/Alaskan Native',
#        'Four-Year Cohort Graduation Rate, Asian',
#        'Four-Year Cohort Graduation Rate, Black/African American',
#        'Four-Year Cohort Graduation Rate, Economically Disadvantaged',
#        'Four-Year Cohort Graduation Rate, English Learners',
#        'Four-Year Cohort Graduation Rate, Hispanic/Latino',
#        'Four-Year Cohort Graduation Rate, Multiracial',
#        'Four-Year Cohort Graduation Rate, Native Hawaiian/Pacific Islander',
#        'Four-Year Cohort Graduation Rate, Special Education',
#        'Four-Year Cohort Graduation Rate, White',
#        'Keystone Algebra I: % of Students Below Basic, Grade 11',
#        'Keystone Algebra I: % of Students Below Basic, Grade 11,  American Indian/Alaskan Native',
#        'Keystone Algebra I: % of Students Below Basic, Grade 11,  Asian',
#        'Keystone Algebra I: % of Students Below Basic, Grade 11,  Black/African American',
#        'Keystone Algebra I: % of Students Below Basic, Grade 11,  Economically Disadvantaged',
#        'Keystone Algebra I: % of Students Below Basic, Grade 11,  English Learners',
#        'Keystone Algebra I: % of Students Below Basic, Grade 11,  Hispanic/Latino',
#        'Keystone Algebra I: % of Students Below Basic, Grade 11,  Multiracial',
#        'Keystone Algebra I: % of Students Below Basic, Grade 11,  Native Hawaiian/Pacific Islander',
#        'Keystone Algebra I: % of Students Below Basic, Grade 11,  Special Education',
#        'Keystone Algebra I: % of Students Below Basic, Grade 11,  White',
#        'Keystone Algebra I: % of Students Proficient or Advanced, Grade 11',
#        'Keystone Algebra I: % of Students Proficient or Advanced, Grade 11,  American Indian/Alaskan Native',
#        'Keystone Algebra I: % of Students Proficient or Advanced, Grade 11,  Asian',
#        'Keystone Algebra I: % of Students Proficient or Advanced, Grade 11,  Black/African American',
#        'Keystone Algebra I: % of Students Proficient or Advanced, Grade 11,  Economically Disadvantaged',
#        'Keystone Algebra I: % of Students Proficient or Advanced, Grade 11,  English Learners',
#        'Keystone Algebra I: % of Students Proficient or Advanced, Grade 11,  Hispanic/Latino',
#        'Keystone Algebra I: % of Students Proficient or Advanced, Grade 11,  Multiracial',
#        'Keystone Algebra I: % of Students Proficient or Advanced, Grade 11,  Native Hawaiian/Pacific Islander',
#        'Keystone Algebra I: % of Students Proficient or Advanced, Grade 11,  Special Education',
#        'Keystone Algebra I: % of Students Proficient or Advanced, Grade 11,  White',
#        'Keystone Biology: % of Students Below Basic, Grade 11',
#        'Keystone Biology: % of Students Below Basic, Grade 11,  American Indian/Alaskan Native',
#        'Keystone Biology: % of Students Below Basic, Grade 11,  Asian',
#        'Keystone Biology: % of Students Below Basic, Grade 11,  Black/African American',
#        'Keystone Biology: % of Students Below Basic, Grade 11,  Economically Disadvantaged',
#        'Keystone Biology: % of Students Below Basic, Grade 11,  English Learners',
#        'Keystone Biology: % of Students Below Basic, Grade 11,  Hispanic/Latino',
#        'Keystone Biology: % of Students Below Basic, Grade 11,  Multiracial',
#        'Keystone Biology: % of Students Below Basic, Grade 11,  Native Hawaiian/Pacific Islander',
#        'Keystone Biology: % of Students Below Basic, Grade 11,  Special Education',
#        'Keystone Biology: % of Students Below Basic, Grade 11,  White',
#        'Keystone Biology: % of Students Proficient or Advanced, Grade 11',
#        'Keystone Biology: % of Students Proficient or Advanced, Grade 11,  American Indian/Alaskan Native',
#        'Keystone Biology: % of Students Proficient or Advanced, Grade 11,  Asian',
#        'Keystone Biology: % of Students Proficient or Advanced, Grade 11,  Black/African American',
#        'Keystone Biology: % of Students Proficient or Advanced, Grade 11,  Economically Disadvantaged',
#        'Keystone Biology: % of Students Proficient or Advanced, Grade 11,  English Learners',
#        'Keystone Biology: % of Students Proficient or Advanced, Grade 11,  Hispanic/Latino',
#        'Keystone Biology: % of Students Proficient or Advanced, Grade 11,  Multiracial',
#        'Keystone Biology: % of Students Proficient or Advanced, Grade 11,  Native Hawaiian/Pacific Islander',
#        'Keystone Biology: % of Students Proficient or Advanced, Grade 11,  Special Education',
#        'Keystone Biology: % of Students Proficient or Advanced, Grade 11,  White',
#        'Keystone Literature: % of Students Below Basic, Grade 11',
#        'Keystone Literature: % of Students Below Basic, Grade 11,  American Indian/Alaskan Native',
#        'Keystone Literature: % of Students Below Basic, Grade 11,  Asian',
#        'Keystone Literature: % of Students Below Basic, Grade 11,  Black/African American',
#        'Keystone Literature: % of Students Below Basic, Grade 11,  Economically Disadvantaged',
#        'Keystone Literature: % of Students Below Basic, Grade 11,  English Learners',
#        'Keystone Literature: % of Students Below Basic, Grade 11,  Hispanic/Latino',
#        'Keystone Literature: % of Students Below Basic, Grade 11,  Multiracial',
#        'Keystone Literature: % of Students Below Basic, Grade 11,  Native Hawaiian/Pacific Islander',
#        'Keystone Literature: % of Students Below Basic, Grade 11,  Special Education',
#        'Keystone Literature: % of Students Below Basic, Grade 11,  White',
#        'Keystone Literature: % of Students Proficient or Advanced, Grade 11',
#        'Keystone Literature: % of Students Proficient or Advanced, Grade 11,  American Indian/Alaskan Native',
#        'Keystone Literature: % of Students Proficient or Advanced, Grade 11,  Asian',
#        'Keystone Literature: % of Students Proficient or Advanced, Grade 11,  Black/African American',
#        'Keystone Literature: % of Students Proficient or Advanced, Grade 11,  Economically Disadvantaged',
#        'Keystone Literature: % of Students Proficient or Advanced, Grade 11,  English Learners',
#        'Keystone Literature: % of Students Proficient or Advanced, Grade 11,  Hispanic/Latino',
#        'Keystone Literature: % of Students Proficient or Advanced, Grade 11,  Multiracial',
#        'Keystone Literature: % of Students Proficient or Advanced, Grade 11,  Native Hawaiian/Pacific Islander',
#        'Keystone Literature: % of Students Proficient or Advanced, Grade 11,  Special Education',
#        'Keystone Literature: % of Students Proficient or Advanced, Grade 11,  White',
#        '% of 11th Grade Students Proficient on All Three Keystones',
#        '% of 11th Grade Students Proficient on All Three Keystones - American Indian/Alaskan Native',
#        '% of 11th Grade Students Proficient on All Three Keystones - Asian',
#        '% of 11th Grade Students Proficient on All Three Keystones - Black/African American',
#        '% of 11th Grade Students Proficient on All Three Keystones - Economically Disadvantaged',
#        '% of 11th Grade Students Proficient on All Three Keystones - English Learner',
#        '% of 11th Grade Students Proficient on All Three Keystones - Hispanic/Latino',
#        '% of 11th Grade Students Proficient on All Three Keystones - Multiracial',
#        '% of 11th Grade Students Proficient on All Three Keystones - Native Hawaiian/Alaskan Native',
#        '% of 11th Grade Students Proficient on All Three Keystones - Special Education',
#        '% of 11th Grade Students Proficient on All Three Keystones - White',
#        '% of 12th Grade CTE Students Meeting Industry Standards',
#        'Ninth-Grade On-Track Rate',
#        '% of Students Receiving Zero Out-of-School Suspensions',
#        'Percent of Metrics Improving,  All Students',
#        'Percent of Metrics Improving,  American Indian/Alaskan Native',
#        'Percent of Metrics Improving,  Asian',
#        'Percent of Metrics Improving,  Black/African American',
#        'Percent of Metrics Improving,  Economically Disadvantaged',
#        'Percent of Metrics Improving,  English Learners',
#        'Percent of Metrics Improving,  Hispanic/Latino',
#        'Percent of Metrics Improving,  Multiracial',
#        'Percent of Metrics Improving,  Native Hawaiian/Pacific Islander',
#        'Percent of Metrics Improving,  Special Education',
#        'Percent of Metrics Improving,  White',
#        'Percent of Targets Met,  All Students',
#        'Percent of Targets Met,  American Indian/Alaskan Native',
#        'Percent of Targets Met,  Asian',
#        'Percent of Targets Met,  Black/African American',
#        'Percent of Targets Met,  Economically Disadvantaged',
#        'Percent of Targets Met,  English Learners',
#        'Percent of Targets Met,  Hispanic/Latino',
#        'Percent of Targets Met,  Multiracial',
#        'Percent of Targets Met,  Native Hawaiian/Pacific Islander',
#        'Percent of Targets Met,  Special Education',
#        'Percent of Targets Met,  White',
#        'PSSA ELA: % of Students Below Basic, Grades 3-8',
#        'PSSA ELA: % of Students Below Basic, Grades 3-8,  American Indian/Alaskan Native',
#        'PSSA ELA: % of Students Below Basic, Grades 3-8,  Asian',
#        'PSSA ELA: % of Students Below Basic, Grades 3-8,  Black/African American',
#        'PSSA ELA: % of Students Below Basic, Grades 3-8,  Economically Disadvantaged',
#        'PSSA ELA: % of Students Below Basic, Grades 3-8,  English Learners',
#        'PSSA ELA: % of Students Below Basic, Grades 3-8,  Hispanic/Latino',
#        'PSSA ELA: % of Students Below Basic, Grades 3-8,  Multiracial',
#        'PSSA ELA: % of Students Below Basic, Grades 3-8,  Native Hawaiian/Pacific Islander',
#        'PSSA ELA: % of Students Below Basic, Grades 3-8,  Special Education',
#        'PSSA ELA: % of Students Below Basic, Grades 3-8,  White',
#        'PSSA ELA: % of Students Below Basic, Grade 3',
#        'PSSA ELA: % of Students Below Basic, Grade 3,  American Indian/Alaskan Native',
#        'PSSA ELA: % of Students Below Basic, Grade 3,  Asian',
#        'PSSA ELA: % of Students Below Basic, Grade 3,  Black/African American',
#        'PSSA ELA: % of Students Below Basic, Grade 3,  Economically Disadvantaged',
#        'PSSA ELA: % of Students Below Basic, Grade 3,  English Learners',
#        'PSSA ELA: % of Students Below Basic, Grade 3,  Hispanic/Latino',
#        'PSSA ELA: % of Students Below Basic, Grade 3,  Multiracial',
#        'PSSA ELA: % of Students Below Basic, Grade 3,  Native Hawaiian/Pacific Islander',
#        'PSSA ELA: % of Students Below Basic, Grade 3,  Special Education',
#        'PSSA ELA: % of Students Below Basic, Grade 3,  White',
#        'PSSA ELA: % of Students Proficient or Advanced, Grades 3-8',
#        'PSSA ELA: % of Students Proficient or Advanced, Grades 3-8, American Indian/Alaskan Native',
#        'PSSA ELA: % of Students Proficient or Advanced, Grades 3-8, Asian',
#        'PSSA ELA: % of Students Proficient or Advanced, Grades 3-8, Black/African American',
#        'PSSA ELA: % of Students Proficient or Advanced, Grades 3-8, Economically Disadvantaged',
#        'PSSA ELA: % of Students Proficient or Advanced, Grades 3-8, English Learners',
#        'PSSA ELA: % of Students Proficient or Advanced, Grades 3-8, Hispanic/Latino',
#        'PSSA ELA: % of Students Proficient or Advanced, Grades 3-8, Multiracial',
#        'PSSA ELA: % of Students Proficient or Advanced, Grades 3-8, Native Hawaiian/Pacific Islander',
#        'PSSA ELA: % of Students Proficient or Advanced, Grades 3-8, Special Education',
#        'PSSA ELA: % of Students Proficient or Advanced, Grades 3-8, White',
#        'PSSA ELA: % of Students Proficient or Advanced, Grade 3',
#        'PSSA ELA: % of Students Proficient or Advanced, Grade 3, American Indian/Alaskan Native',
#        'PSSA ELA: % of Students Proficient or Advanced, Grade 3, Asian',
#        'PSSA ELA: % of Students Proficient or Advanced, Grade 3, Black/African American',
#        'PSSA ELA: % of Students Proficient or Advanced, Grade 3, Economically Disadvantaged',
#        'PSSA ELA: % of Students Proficient or Advanced, Grade 3, English Learners',
#        'PSSA ELA: % of Students Proficient or Advanced, Grade 3, Hispanic/Latino',
#        'PSSA ELA: % of Students Proficient or Advanced, Grade 3, Multiracial',
#        'PSSA ELA: % of Students Proficient or Advanced, Grade 3, Native Hawaiian/Pacific Islander',
#        'PSSA ELA: % of Students Proficient or Advanced, Grade 3, Special Education',
#        'PSSA ELA: % of Students Proficient or Advanced, Grade 3, White',
#        'PSSA Math: % of Students Below Basic, Grades 3-8',
#        'PSSA Math: % of Students Below Basic, Grades 3-8,  American Indian/Alaskan Native',
#        'PSSA Math: % of Students Below Basic, Grades 3-8,  Asian',
#        'PSSA Math: % of Students Below Basic, Grades 3-8,  Black/African American',
#        'PSSA Math: % of Students Below Basic, Grades 3-8,  Economically Disadvantaged',
#        'PSSA Math: % of Students Below Basic, Grades 3-8,  English Learners',
#        'PSSA Math: % of Students Below Basic, Grades 3-8,  Hispanic/Latino',
#        'PSSA Math: % of Students Below Basic, Grades 3-8,  Multiracial',
#        'PSSA Math: % of Students Below Basic, Grades 3-8,  Native Hawaiian/Pacific Islander',
#        'PSSA Math: % of Students Below Basic, Grades 3-8,  Special Education',
#        'PSSA Math: % of Students Below Basic, Grades 3-8,  White',
#        'PSSA Math: % of Students Below Basic, Grade 3',
#        'PSSA Math: % of Students Below Basic, Grade 3,  American Indian/Alaskan Native',
#        'PSSA Math: % of Students Below Basic, Grade 3,  Asian',
#        'PSSA Math: % of Students Below Basic, Grade 3,  Black/African American',
#        'PSSA Math: % of Students Below Basic, Grade 3,  Economically Disadvantaged',
#        'PSSA Math: % of Students Below Basic, Grade 3,  English Learners',
#        'PSSA Math: % of Students Below Basic, Grade 3,  Hispanic/Latino',
#        'PSSA Math: % of Students Below Basic, Grade 3,  Multiracial',
#        'PSSA Math: % of Students Below Basic, Grade 3,  Native Hawaiian/Pacific Islander',
#        'PSSA Math: % of Students Below Basic, Grade 3,  Special Education',
#        'PSSA Math: % of Students Below Basic, Grade 3,  White',
#        'PSSA Math: % of Students Proficient or Advanced, Grades 3-8',
#        'PSSA Math: % of Students Proficient or Advanced, Grades 3-8, American Indian/Alaskan Native',
#        'PSSA Math: % of Students Proficient or Advanced, Grades 3-8, Asian',
#        'PSSA Math: % of Students Proficient or Advanced, Grades 3-8, Black/African American',
#        'PSSA Math: % of Students Proficient or Advanced, Grades 3-8, Economically Disadvantaged',
#        'PSSA Math: % of Students Proficient or Advanced, Grades 3-8, English Learners',
#        'PSSA Math: % of Students Proficient or Advanced, Grades 3-8, Hispanic/Latino',
#        'PSSA Math: % of Students Proficient or Advanced, Grades 3-8, Multiracial',
#        'PSSA Math: % of Students Proficient or Advanced, Grades 3-8, Native Hawaiian/Pacific Islander',
#        'PSSA Math: % of Students Proficient or Advanced, Grades 3-8, Special Education',
#        'PSSA Math: % of Students Proficient or Advanced, Grades 3-8, White',
#        'PSSA Math: % of Students Proficient or Advanced, Grade 3',
#        'PSSA Math: % of Students Proficient or Advanced, Grade 3,  American Indian/Alaskan Native',
#        'PSSA Math: % of Students Proficient or Advanced, Grade 3,  Asian',
#        'PSSA Math: % of Students Proficient or Advanced, Grade 3,  Black/African American',
#        'PSSA Math: % of Students Proficient or Advanced, Grade 3,  Economically Disadvantaged',
#        'PSSA Math: % of Students Proficient or Advanced, Grade 3,  English Learners',
#        'PSSA Math: % of Students Proficient or Advanced, Grade 3,  Hispanic/Latino',
#        'PSSA Math: % of Students Proficient or Advanced, Grade 3,  Multiracial',
#        'PSSA Math: % of Students Proficient or Advanced, Grade 3,  Native Hawaiian/Pacific Islander',
#        'PSSA Math: % of Students Proficient or Advanced, Grade 3,  Special Education',
#        'PSSA Math: % of Students Proficient or Advanced, Grade 3,  White',
#        'PSSA Science: % of Students Below Basic, Grades 4-8',
#        'PSSA Science: % of Students Below Basic, Grades 4-8,  American Indian/Alaskan Native',
#        'PSSA Science: % of Students Below Basic, Grades 4-8,  Asian',
#        'PSSA Science: % of Students Below Basic, Grades 4-8,  Black/African American',
#        'PSSA Science: % of Students Below Basic, Grades 4-8,  Economically Disadvantaged',
#        'PSSA Science: % of Students Below Basic, Grades 4-8,  English Learners',
#        'PSSA Science: % of Students Below Basic, Grades 4-8,  Hispanic/Latino',
#        'PSSA Science: % of Students Below Basic, Grades 4-8,  Multiracial',
#        'PSSA Science: % of Students Below Basic, Grades 4-8,  Native Hawaiian/Pacific Islander',
#        'PSSA Science: % of Students Below Basic, Grades 4-8,  Special Education',
#        'PSSA Science: % of Students Below Basic, Grades 4-8,  White',
#        'PSSA Science: % of Students Proficient or Advanced, Grades 4-8',
#        'PSSA Science: % of Students Proficient or Advanced, Grades 4-8,  American Indian/Alaskan Native',
#        'PSSA Science: % of Students Proficient or Advanced, Grades 4-8,  Asian',
#        'PSSA Science: % of Students Proficient or Advanced, Grades 4-8,  Black/African American',
#        'PSSA Science: % of Students Proficient or Advanced, Grades 4-8,  Economically Disadvantaged',
#        'PSSA Science: % of Students Proficient or Advanced, Grades 4-8,  English Learners',
#        'PSSA Science: % of Students Proficient or Advanced, Grades 4-8,  Hispanic/Latino',
#        'PSSA Science: % of Students Proficient or Advanced, Grades 4-8,  Multiracial',
#        'PSSA Science: % of Students Proficient or Advanced, Grades 4-8,  Native Hawaiian/Pacific Islander',
#        'PSSA Science: % of Students Proficient or Advanced, Grades 4-8,  Special Education',
#        'PSSA Science: % of Students Proficient or Advanced, Grades 4-8,  White',
#        '% of Teachers Rated as Distinguished',
#        '% of Teachers Rated as Proficient',
#        '% of Teachers Attending at Least 90% of Instructional Days',
#        'Year-to-Year Teacher Retention'], dtype=object)

# %%
# Create a list a metrics to keep
high_school_metrics_to_keep = [
       'Admission Type',
       '% of Students Attending at Least 90% of Instructional Days',
       'Number of Dropouts - Last School of Touch (Grades 7-12)',
       '# of Students Served Over the Full Year', 
       'October 1 Enrollment',
       '% of Students Completing the FAFSA by End of 12th Grade',
       'First-Fall Matriculation', 
       'Four-Year Cohort Graduation Rate',
       'Keystone Algebra I: % of Students Below Basic, Grade 11',
       'Keystone Algebra I: % of Students Proficient or Advanced, Grade 11',
       'Keystone Biology: % of Students Below Basic, Grade 11',
       'Keystone Biology: % of Students Proficient or Advanced, Grade 11',
       'Keystone Literature: % of Students Below Basic, Grade 11',
       'Keystone Literature: % of Students Proficient or Advanced, Grade 11',
       '% of 11th Grade Students Proficient on All Three Keystones',
       '% of 12th Grade CTE Students Meeting Industry Standards',
       'Ninth-Grade On-Track Rate',
       '% of Students Receiving Zero Out-of-School Suspensions',
       'Percent of Metrics Improving,  All Students',
       '% of Teachers Rated as Distinguished',
       '% of Teachers Rated as Proficient',
       '% of Teachers Attending at Least 90% of Instructional Days',
       'Year-to-Year Teacher Retention'
]
print("Number of metrics to keep:", len(high_school_metrics_to_keep))
# Out:
# Number of metrics to keep: 23

# %%
# Reduce the number of rows by keeping only the rows with a 'metric' in high_school_metrics_to_keep
high_school_metrics_df = high_school_metrics_df[high_school_metrics_df['metric'].isin(high_school_metrics_to_keep)]

# Print info for cleaned dataframe
high_school_count = high_school_metrics_df['school_name'].nunique()
print("Number of High Schools:", high_school_count)
high_school_metrics_count = high_school_metrics_df['metric'].nunique()
print("Number of High School metrics:", high_school_metrics_count)
high_school_metrics_df.info()
# Out:
# Number of High Schools: 84
# Number of High School metrics: 23
# <class 'pandas.core.frame.DataFrame'>
# Index: 1932 entries, 0 to 83719
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   accountability_year  1932 non-null   object
#  1   school_id            1932 non-null   int64
#  2   school_name          1932 non-null   object
#  3   report_type          1932 non-null   object
#  4   metric               1932 non-null   object
#  5   numerator            1398 non-null   float64
#  6   denominator          1398 non-null   float64
#  7   metric_score         1932 non-null   object
#  8   score_previous       1847 non-null   object
#  9   score_change         1848 non-null   object
#  10  tier                 921 non-null    object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 181.1+ KB

# %%
# Verify the new dataframe has the correct number of metrics

# Create list of high school metrics
high_school_metrics = high_school_metrics_df['metric'].unique()

# Convert the lists to sets
high_school_metrics_set = set(high_school_metrics)
high_school_metrics_to_keep_set = set(high_school_metrics_to_keep)

# Find elements only in high_school_metrics
only_in_high_school_metrics = high_school_metrics_set.difference(high_school_metrics_to_keep_set)

# Find elements only in high_school_metrics_to_keep
only_in_high_school_to_keep_metrics = high_school_metrics_to_keep_set.difference(high_school_metrics_set)

# Print the results
print("Number of high_school_metrics:", len(high_school_metrics_set))
print("Number of high_school_metrics_to_keep:", len(high_school_metrics_to_keep_set))
print("Only in high_school_metrics:", only_in_high_school_metrics)
print("Only in high_school_metrics_to_keep:", only_in_high_school_to_keep_metrics)
# Out:
# Number of high_school_metrics: 23
# Number of high_school_metrics_to_keep: 23
# Only in high_school_metrics: set()
# Only in high_school_metrics_to_keep: set()

# %%
middle_school_metrics_df.head()
# Out:
#      accountability_year  school_id               school_name    report_type  \
# 1300           2022-2023       1130  William T. Tilden School  Middle School
# 1301           2022-2023       1130  William T. Tilden School  Middle School
# 1302           2022-2023       1130  William T. Tilden School  Middle School
# 1303           2022-2023       1130  William T. Tilden School  Middle School
# 1304           2022-2023       1130  William T. Tilden School  Middle School
#
#                                                  metric  numerator  \
# 1300                                     Admission Type        NaN
# 1301  % of Students Attending Less Than 80% of Instr...       47.0
# 1302  % of Students Attending 80-85% of Instructiona...       22.0
# 1303  % of Students Attending 85-90% of Instructiona...       55.0
# 1304  % of Students Attending at Least 90% of Instru...      280.0
#
#       denominator metric_score score_previous    score_change       tier
# 1300          NaN    Catchment   Neighborhood  Not Applicable        NaN
# 1301        404.0         11.6            NaN             NaN        NaN
# 1302        404.0          5.5            NaN             NaN        NaN
# 1303        404.0         13.6            NaN             NaN        NaN
# 1304        404.0         69.3           50.5            18.8  Improving

# %%
# list all the middle school metrics
ms_unique_metrics = middle_school_metrics_df['metric'].unique()
# ms_unique_metrics

# %%
# Create a list a metrics to keep
middle_school_metrics_to_keep = [
       'Admission Type',
       '% of Students Attending at Least 90% of Instructional Days',
       'Number of Dropouts - Last School of Touch (Grades 7-12)',
       '# of Students Served Over the Full Year', 'October 1 Enrollment',
       '% of Students Receiving Zero Out-of-School Suspensions',
       'Percent of Metrics Improving,  All Students',
       'PSSA ELA: % of Students Below Basic, Grades 3-8',
       'PSSA ELA: % of Students Proficient or Advanced, Grades 3-8',
       'PSSA Math: % of Students Below Basic, Grades 3-8',
       'PSSA Math: % of Students Proficient or Advanced, Grades 3-8',
       'PSSA Science: % of Students Below Basic, Grades 4-8',
       'PSSA Science: % of Students Proficient or Advanced, Grades 4-8',
       '% of Teachers Rated as Distinguished',
       '% of Teachers Rated as Proficient',
       '% of Teachers Attending at Least 90% of Instructional Days',
       'Year-to-Year Teacher Retention'
]

print("Number of metrics to keep:", len(middle_school_metrics_to_keep))
# Out:
# Number of metrics to keep: 17

# %%
# Reduce the number of rows by keeping only the rows with a 'metric' in middle_school_metrics_to_keep
middle_school_metrics_df = middle_school_metrics_df[middle_school_metrics_df['metric'].isin(middle_school_metrics_to_keep)]

# Print info for cleaned dataframe
middle_school_count = middle_school_metrics_df['school_name'].nunique()
print("Number of Middle Schools:", middle_school_count)
middle_school_metrics_count = middle_school_metrics_df['metric'].nunique()
print("Number of Middle School metrics:", middle_school_metrics_count)
middle_school_metrics_df.info()
# Out:
# Number of Middle Schools: 29
# Number of Middle School metrics: 17
# <class 'pandas.core.frame.DataFrame'>
# Index: 493 entries, 1300 to 77739
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   accountability_year  493 non-null    object
#  1   school_id            493 non-null    int64
#  2   school_name          493 non-null    object
#  3   report_type          493 non-null    object
#  4   metric               493 non-null    object
#  5   numerator            338 non-null    float64
#  6   denominator          338 non-null    float64
#  7   metric_score         493 non-null    object
#  8   score_previous       463 non-null    object
#  9   score_change         464 non-null    object
#  10  tier                 271 non-null    object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 46.2+ KB

# %%
# Verify the new dataframe has the correct number of metrics

# Create list of middle school metrics
middle_school_metrics = middle_school_metrics_df['metric'].unique()

# Convert the lists to sets
middle_school_metrics_set = set(middle_school_metrics)
middle_school_metrics_to_keep_set = set(middle_school_metrics_to_keep)

# Find elements only in middle_school_metrics
only_in_middle_school_metrics = middle_school_metrics_set.difference(middle_school_metrics_to_keep_set)

# Find elements only in middle_school_metrics_to_keep
only_in_middle_school_to_keep_metrics = middle_school_metrics_to_keep_set.difference(middle_school_metrics_set)

# Print the results
print("Number of middle_school_metrics:", len(middle_school_metrics_set))
print("Number of middle_school_metrics_to_keep:", len(middle_school_metrics_to_keep_set))
print("Only in middle_school_metrics:", only_in_middle_school_metrics)
print("Only in middle_school_metrics_to_keep:", only_in_middle_school_to_keep_metrics)
# Out:
# Number of middle_school_metrics: 17
# Number of middle_school_metrics_to_keep: 17
# Only in middle_school_metrics: set()
# Only in middle_school_metrics_to_keep: set()

# %%
ktoeight_school_metrics_df.head()
# Out:
#      accountability_year  school_id        school_name report_type  \
# 1820           2022-2023       1200  John Barry School  K-8 School
# 1821           2022-2023       1200  John Barry School  K-8 School
# 1822           2022-2023       1200  John Barry School  K-8 School
# 1823           2022-2023       1200  John Barry School  K-8 School
# 1824           2022-2023       1200  John Barry School  K-8 School
#
#                                                  metric  numerator  \
# 1820                                     Admission Type        NaN
# 1821  % of Students Attending Less Than 80% of Instr...      205.0
# 1822  % of Students Attending 80-85% of Instructiona...       78.0
# 1823  % of Students Attending 85-90% of Instructiona...       93.0
# 1824  % of Students Attending at Least 90% of Instru...      226.0
#
#       denominator metric_score score_previous    score_change       tier
# 1820          NaN    Catchment   Neighborhood  Not Applicable        NaN
# 1821        602.0         34.1            NaN             NaN        NaN
# 1822        602.0           13            NaN             NaN        NaN
# 1823        602.0         15.5            NaN             NaN        NaN
# 1824        602.0         37.5             27            10.5  Improving

# %%
# list all the high school metrics
ktes_unique_metrics = ktoeight_school_metrics_df['metric'].unique()
# ktes_unique_metrics

# %%
# Create a list a metrics to keep
ktoeight_school_metrics_to_keep = [
       'Admission Type',
       '% of Students Attending at Least 90% of Instructional Days',
       'Number of Dropouts - Last School of Touch (Grades 7-12)',
       '# of Students Served Over the Full Year', 'October 1 Enrollment',
       '% of Students Receiving Zero Out-of-School Suspensions',
       'Percent of Metrics Improving,  All Students',
       'PSSA ELA: % of Students Below Basic, Grades 3-8',
       'PSSA ELA: % of Students Below Basic, Grade 3',
       'PSSA ELA: % of Students Proficient or Advanced, Grades 3-8',
       'PSSA ELA: % of Students Proficient or Advanced, Grade 3',
       'PSSA Math: % of Students Below Basic, Grades 3-8',
       'PSSA Math: % of Students Below Basic, Grade 3',
       'PSSA Math: % of Students Proficient or Advanced, Grades 3-8',
       'PSSA Math: % of Students Proficient or Advanced, Grade 3',
       'PSSA Science: % of Students Below Basic, Grades 4-8',
       'PSSA Science: % of Students Proficient or Advanced, Grades 4-8',
       '% of Teachers Rated as Distinguished',
       '% of Teachers Rated as Proficient',
       '% of Teachers Attending at Least 90% of Instructional Days',
       'Year-to-Year Teacher Retention'
]

print("Number of metrics to keep:", len(ktoeight_school_metrics_to_keep))
# Out:
# Number of metrics to keep: 21

# %%
# Reduce the number of rows by keeping only the rows with a 'metric' in ktoeight_school_metrics_to_keep
ktoeight_school_metrics_df = ktoeight_school_metrics_df[ktoeight_school_metrics_df['metric'].isin(ktoeight_school_metrics_to_keep)]

# Print info for cleaned dataframe
ktoeight_school_count = ktoeight_school_metrics_df['school_name'].nunique()
print("Number of K-8 Schools:", ktoeight_school_count)
ktoeight_school_metrics_count = ktoeight_school_metrics_df['metric'].nunique()
print("Number of K-8 School metrics:", ktoeight_school_metrics_count)
ktoeight_school_metrics_df.info()
# Out:
# Number of K-8 Schools: 154
# Number of K-8 School metrics: 21
# <class 'pandas.core.frame.DataFrame'>
# Index: 3234 entries, 1820 to 83979
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   accountability_year  3234 non-null   object
#  1   school_id            3234 non-null   int64
#  2   school_name          3234 non-null   object
#  3   report_type          3234 non-null   object
#  4   metric               3234 non-null   object
#  5   numerator            2379 non-null   float64
#  6   denominator          2379 non-null   float64
#  7   metric_score         3234 non-null   object
#  8   score_previous       3077 non-null   object
#  9   score_change         3080 non-null   object
#  10  tier                 2053 non-null   object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 303.2+ KB

# %%
# Verify the new dataframe has the correct number of metrics

# Create list of k-8 school metrics
ktoeight_school_metrics = ktoeight_school_metrics_df['metric'].unique()

# Convert the lists to sets
ktoeight_school_metrics_set = set(ktoeight_school_metrics)
ktoeight_school_metrics_to_keep_set = set(ktoeight_school_metrics_to_keep)

# Find elements only in ktoeight_school_metrics
only_in_ktoeight_school_metrics = ktoeight_school_metrics_set.difference(ktoeight_school_metrics_to_keep_set)

# Find elements only in ktoeight_school_metrics_to_keep
only_in_ktoeight_school_to_keep_metrics = ktoeight_school_metrics_to_keep_set.difference(ktoeight_school_metrics_set)

# Print the results
print("Number of ktoeight_school_metrics:", len(ktoeight_school_metrics_set))
print("Number of ktoeight_school_metrics_to_keep:", len(ktoeight_school_metrics_to_keep_set))
print("Only in ktoeight_school_metrics:", only_in_ktoeight_school_metrics)
print("Only in ktoeight_school_metrics_to_keep:", only_in_ktoeight_school_to_keep_metrics)
# Out:
# Number of ktoeight_school_metrics: 21
# Number of ktoeight_school_metrics_to_keep: 21
# Only in ktoeight_school_metrics: set()
# Only in ktoeight_school_metrics_to_keep: set()

# %%
elementary_school_metrics_df.head()
# Out:
#      accountability_year  school_id                 school_name  \
# 2340           2022-2023       1250  Joseph W. Catharine School
# 2341           2022-2023       1250  Joseph W. Catharine School
# 2342           2022-2023       1250  Joseph W. Catharine School
# 2343           2022-2023       1250  Joseph W. Catharine School
# 2344           2022-2023       1250  Joseph W. Catharine School
#
#             report_type                                             metric  \
# 2340  Elementary School                                     Admission Type
# 2341  Elementary School  % of Students Attending Less Than 80% of Instr...
# 2342  Elementary School  % of Students Attending 80-85% of Instructiona...
# 2343  Elementary School  % of Students Attending 85-90% of Instructiona...
# 2344  Elementary School  % of Students Attending at Least 90% of Instru...
#
#       numerator  denominator metric_score score_previous    score_change  \
# 2340        NaN          NaN    Catchment   Neighborhood  Not Applicable
# 2341       60.0        447.0         13.4            NaN             NaN
# 2342       27.0        447.0            6            NaN             NaN
# 2343       62.0        447.0         13.9            NaN             NaN
# 2344      298.0        447.0         66.7           56.1            10.6
#
#            tier
# 2340        NaN
# 2341        NaN
# 2342        NaN
# 2343        NaN
# 2344  Improving

# %%
# list all the high school metrics
es_unique_metrics = elementary_school_metrics_df['metric'].unique()
# es_unique_metrics

# %%
# Create a list a metrics to keep
elementary_school_metrics_to_keep = [
       'Admission Type',
       '% of Students Attending at Least 90% of Instructional Days',
       '# of Students Served Over the Full Year', 'October 1 Enrollment',
       '% of Students Receiving Zero Out-of-School Suspensions',
       'Percent of Metrics Improving,  All Students',
       'PSSA ELA: % of Students Below Basic, Grades 3-8',
       'PSSA ELA: % of Students Below Basic, Grade 3',
       'PSSA ELA: % of Students Proficient or Advanced, Grades 3-8',
       'PSSA ELA: % of Students Proficient or Advanced, Grade 3',
       'PSSA Math: % of Students Below Basic, Grades 3-8',
       'PSSA Math: % of Students Below Basic, Grade 3',
       'PSSA Math: % of Students Proficient or Advanced, Grades 3-8',
       'PSSA Math: % of Students Proficient or Advanced, Grade 3',
       'PSSA Science: % of Students Below Basic, Grades 4-8',
       'PSSA Science: % of Students Proficient or Advanced, Grades 4-8',
       '% of Teachers Rated as Distinguished',
       '% of Teachers Rated as Proficient',
       '% of Teachers Attending at Least 90% of Instructional Days',
       'Year-to-Year Teacher Retention'
]

print("Number of metrics to keep:", len(elementary_school_metrics_to_keep))
# Out:
# Number of metrics to keep: 20

# %%
# Reduce the number of rows by keeping only the rows with a 'metric' in elementary_school_metrics_to_keep
elementary_school_metrics_df = elementary_school_metrics_df[elementary_school_metrics_df['metric'].isin(elementary_school_metrics_to_keep)]

# Print info for cleaned dataframe
elementary_school_count = elementary_school_metrics_df['school_name'].nunique()
print("Number of Elementary Schools:", elementary_school_count)
elementary_school_metrics_count = elementary_school_metrics_df['metric'].nunique()
print("Number of Elementary School metrics:", elementary_school_metrics_count)
elementary_school_metrics_df.info()
# Out:
# Number of Elementary Schools: 56
# Number of Elementary School metrics: 20
# <class 'pandas.core.frame.DataFrame'>
# Index: 1120 entries, 2340 to 82939
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   accountability_year  1120 non-null   object
#  1   school_id            1120 non-null   int64
#  2   school_name          1120 non-null   object
#  3   report_type          1120 non-null   object
#  4   metric               1120 non-null   object
#  5   numerator            886 non-null    float64
#  6   denominator          886 non-null    float64
#  7   metric_score         1120 non-null   object
#  8   score_previous       1064 non-null   object
#  9   score_change         1064 non-null   object
#  10  tier                 691 non-null    object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 105.0+ KB

# %%
# Verify the new dataframe has the correct number of metrics

# Create list of elemenarty school metrics
elementary_school_metrics = elementary_school_metrics_df['metric'].unique()

# Convert the lists to sets
elementary_school_metrics_set = set(elementary_school_metrics)
elementary_school_metrics_to_keep_set = set(elementary_school_metrics_to_keep)

# Find elements only in elementary_school_metrics
only_in_elementary_school_metrics = elementary_school_metrics_set.difference(elementary_school_metrics_to_keep_set)

# Find elements only in elementary_school_metrics
only_in_elementary_school_to_keep_metrics = elementary_school_metrics_to_keep_set.difference(elementary_school_metrics_set)

# Print the results
print("Number of elementary_school_metrics:", len(elementary_school_metrics_set))
print("Number of elementary_school_metrics_to_keep:", len(elementary_school_metrics_to_keep_set))
print("Only in elementary_school_metrics:", only_in_elementary_school_metrics)
print("Only in elementary_school_metrics_to_keep:", only_in_elementary_school_to_keep_metrics)
# Out:
# Number of elementary_school_metrics: 20
# Number of elementary_school_metrics_to_keep: 20
# Only in elementary_school_metrics: set()
# Only in elementary_school_metrics_to_keep: set()

# %%
# Print info for dataframes with reduced rows
print("Number of High Schools:", high_school_count)
print("Number of High School metrics:", high_school_metrics_count)
high_school_metrics_df.info()
print('-' * 60)
print("Number of Middle Schools:", middle_school_count)
print("Number of Middle School metrics:", middle_school_metrics_count)
middle_school_metrics_df.info()
print('-' * 60)
print("Number of K-8 Schools:", ktoeight_school_count)
print("Number of K-8 School metrics:", ktoeight_school_metrics_count)
ktoeight_school_metrics_df.info()
print('-' * 60)
print("Number of Elementary Schools:", elementary_school_count)
print("Number of Elementary School metrics:", elementary_school_metrics_count)
elementary_school_metrics_df.info()
print('-' * 60)
all_schools = high_school_count + middle_school_count + ktoeight_school_count + elementary_school_count
print("Number of Schools:", all_schools)
# Out:
# Number of High Schools: 84
# Number of High School metrics: 23
# <class 'pandas.core.frame.DataFrame'>
# Index: 1932 entries, 0 to 83719
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   accountability_year  1932 non-null   object
#  1   school_id            1932 non-null   int64
#  2   school_name          1932 non-null   object
#  3   report_type          1932 non-null   object
#  4   metric               1932 non-null   object
#  5   numerator            1398 non-null   float64
#  6   denominator          1398 non-null   float64
#  7   metric_score         1932 non-null   object
#  8   score_previous       1847 non-null   object
#  9   score_change         1848 non-null   object
#  10  tier                 921 non-null    object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 181.1+ KB
# ------------------------------------------------------------
# Number of Middle Schools: 29
# Number of Middle School metrics: 17
# <class 'pandas.core.frame.DataFrame'>
# Index: 493 entries, 1300 to 77739
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   accountability_year  493 non-null    object
#  1   school_id            493 non-null    int64
#  2   school_name          493 non-null    object
#  3   report_type          493 non-null    object
#  4   metric               493 non-null    object
#  5   numerator            338 non-null    float64
#  6   denominator          338 non-null    float64
#  7   metric_score         493 non-null    object
#  8   score_previous       463 non-null    object
#  9   score_change         464 non-null    object
#  10  tier                 271 non-null    object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 46.2+ KB
# ------------------------------------------------------------
# Number of K-8 Schools: 154
# Number of K-8 School metrics: 21
# <class 'pandas.core.frame.DataFrame'>
# Index: 3234 entries, 1820 to 83979
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   accountability_year  3234 non-null   object
#  1   school_id            3234 non-null   int64
#  2   school_name          3234 non-null   object
#  3   report_type          3234 non-null   object
#  4   metric               3234 non-null   object
#  5   numerator            2379 non-null   float64
#  6   denominator          2379 non-null   float64
#  7   metric_score         3234 non-null   object
#  8   score_previous       3077 non-null   object
#  9   score_change         3080 non-null   object
#  10  tier                 2053 non-null   object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 303.2+ KB
# ------------------------------------------------------------
# Number of Elementary Schools: 56
# Number of Elementary School metrics: 20
# <class 'pandas.core.frame.DataFrame'>
# Index: 1120 entries, 2340 to 82939
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   accountability_year  1120 non-null   object
#  1   school_id            1120 non-null   int64
#  2   school_name          1120 non-null   object
#  3   report_type          1120 non-null   object
#  4   metric               1120 non-null   object
#  5   numerator            886 non-null    float64
#  6   denominator          886 non-null    float64
#  7   metric_score         1120 non-null   object
#  8   score_previous       1064 non-null   object
#  9   score_change         1064 non-null   object
#  10  tier                 691 non-null    object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 105.0+ KB
# ------------------------------------------------------------
# Number of Schools: 323

# %%
high_school_metrics_df.head()
# Out:
#   accountability_year  school_id               school_name  report_type  \
# 0           2022-2023       1010  John Bartram High School  High School
# 4           2022-2023       1010  John Bartram High School  High School
# 7           2022-2023       1010  John Bartram High School  High School
# 8           2022-2023       1010  John Bartram High School  High School
# 9           2022-2023       1010  John Bartram High School  High School
#
#                                               metric  numerator  denominator  \
# 0                                     Admission Type        NaN          NaN
# 4  % of Students Attending at Least 90% of Instru...      208.0        617.0
# 7  Number of Dropouts - Last School of Touch (Gra...        NaN          NaN
# 8            # of Students Served Over the Full Year        NaN          NaN
# 9                               October 1 Enrollment        NaN          NaN
#
#   metric_score score_previous    score_change         tier
# 0    Catchment   Neighborhood  Not Applicable          NaN
# 4         33.7           33.8            -0.1  Maintaining
# 7           41             54             -13    Improving
# 8          617            642             -25          NaN
# 9          478            489             -11          NaN

# %%
# Pivot the high_school_metrics_df DataFrame to create one row for each school 
hs_metrics_df = high_school_metrics_df.pivot_table(
    index = ['accountability_year', 'school_id', 'school_name', 'report_type'],
    columns = 'metric', 
    values = 'metric_score',
    aggfunc='first'
).reset_index()

hs_metrics_df.head()
# Out:
# metric accountability_year  school_id  \
# 0                2022-2023       1010
# 1                2022-2023       1020
# 2                2022-2023       1030
# 3                2022-2023       1050
# 4                2022-2023       1100
#
# metric                                  school_name  report_type  \
# 0                          John Bartram High School  High School
# 1                     West Philadelphia High School  High School
# 2                         High School of the Future  High School
# 3       Paul Robeson High School for Human Services  High School
# 4                      William L. Sayre High School  High School
#
# metric # of Students Served Over the Full Year  \
# 0                                          617
# 1                                          608
# 2                                          578
# 3                                          341
# 4                                          474
#
# metric % of 11th Grade Students Proficient on All Three Keystones  \
# 0                                                     4.2
# 1                                                       0
# 2                                                     4.8
# 3                                                    15.8
# 4                                                     1.7
#
# metric % of 12th Grade CTE Students Meeting Industry Standards  \
# 0                                     Insufficient Sample
# 1                                                      20
# 2                                     Insufficient Sample
# 3                                     Insufficient Sample
# 4                                     Insufficient Sample
#
# metric % of Students Attending at Least 90% of Instructional Days  \
# 0                                                    33.7
# 1                                                    30.3
# 2                                                    43.4
# 3                                                    67.7
# 4                                                    36.7
#
# metric % of Students Completing the FAFSA by End of 12th Grade  \
# 0                                                    30.7
# 1                                                    30.5
# 2                                                    44.9
# 3                                                    61.2
# 4                                                    19.3
#
# metric % of Students Receiving Zero Out-of-School Suspensions  ...  \
# 0                                                    80.6      ...
# 1                                                    94.6      ...
# 2                                                    90.7      ...
# 3                                                    99.4      ...
# 4                                                    81.2      ...
#
# metric Keystone Algebra I: % of Students Proficient or Advanced, Grade 11  \
# 0                                                     7.3
# 1                                                     9.8
# 2                                                     5.6
# 3                                                    18.4
# 4                                                     3.7
#
# metric Keystone Biology: % of Students Below Basic, Grade 11  \
# 0                                                    61.2
# 1                                                    63.8
# 2                                                    58.1
# 3                                                    34.7
# 4                                                    69.6
#
# metric Keystone Biology: % of Students Proficient or Advanced, Grade 11  \
# 0                                                    17.9
# 1                                                    10.3
# 2                                                     8.6
# 3                                                      24
# 4                                                     1.8
#
# metric Keystone Literature: % of Students Below Basic, Grade 11  \
# 0                                                    56.3
# 1                                                    35.6
# 2                                                    20.9
# 3                                                     5.3
# 4                                                      40
#
# metric Keystone Literature: % of Students Proficient or Advanced, Grade 11  \
# 0                                                    17.2
# 1                                                      17
# 2                                                    30.4
# 3                                                    53.3
# 4                                                    16.4
#
# metric Ninth-Grade On-Track Rate  \
# 0                           71.1
# 1                           76.1
# 2                           62.9
# 3                           72.4
# 4                           87.7
#
# metric Number of Dropouts - Last School of Touch (Grades 7-12)  \
# 0                                                      41
# 1                                                      34
# 2                                                      20
# 3                                                       9
# 4                                                      27
#
# metric October 1 Enrollment Percent of Metrics Improving,  All Students  \
# 0                       478                                        58.3
# 1                       545                                        38.5
# 2                       569                                        58.3
# 3                       313                                          50
# 4                       355                                        33.3
#
# metric Year-to-Year Teacher Retention
# 0                                73.2
# 1                                79.6
# 2                                72.9
# 3                                  90
# 4                                86.1
#
# [5 rows x 27 columns]

# %%
# List the hs_metrics_df columns
# hs_metrics_df.columns

# %%
# Create a list with desireds column order
hs_columns = [
    'accountability_year', 
    'school_id', 
    'school_name', 
    'report_type', 
    'Admission Type', 
    '# of Students Served Over the Full Year', 
    'October 1 Enrollment', 
    '% of 11th Grade Students Proficient on All Three Keystones', 
    'Keystone Algebra I: % of Students Below Basic, Grade 11', 
    'Keystone Algebra I: % of Students Proficient or Advanced, Grade 11', 
    'Keystone Biology: % of Students Below Basic, Grade 11', 
    'Keystone Biology: % of Students Proficient or Advanced, Grade 11', 
    'Keystone Literature: % of Students Below Basic, Grade 11', 
    'Keystone Literature: % of Students Proficient or Advanced, Grade 11', 
    '% of 12th Grade CTE Students Meeting Industry Standards', 
    'Ninth-Grade On-Track Rate', 
    'Percent of Metrics Improving,  All Students', 
    '% of Students Attending at Least 90% of Instructional Days', 
    'Number of Dropouts - Last School of Touch (Grades 7-12)', 
    '% of Students Receiving Zero Out-of-School Suspensions', 
    '% of Students Completing the FAFSA by End of 12th Grade',
    'First-Fall Matriculation',
    'Four-Year Cohort Graduation Rate'
]
# Reorder the DataFrame columns
hs_metrics_df = hs_metrics_df[hs_columns]

# %%
# Rename the Columns with compatible formatting 
hs_metrics_df = hs_metrics_df.rename(columns={
    'accountability_year': 'Year', 
    'school_id': 'school_id', 
    'school_name': 'School_Name', 
    'report_type': 'Report_Type', 
    'Admission Type': 'Admission_Type', 
    '# of Students Served Over the Full Year': 'Number_Students_Served_Full_Year', 
    'October 1 Enrollment': 'October_1_Enrollment', 
    '% of 11th Grade Students Proficient on All Three Keystones': 'Percent_11th_Grade_Students_Proficient_All_Three_Keystones', 
    'Keystone Algebra I: % of Students Below Basic, Grade 11': 'Percent_11th_Grade_Students_Below_Basic_Keystone_Algebra_I', 
    'Keystone Algebra I: % of Students Proficient or Advanced, Grade 11': 'Percent_11th_Grade_Students_Proficient_Keystone_Algebra_I', 
    'Keystone Biology: % of Students Below Basic, Grade 11': 'Percent_11th_Grade_Students_Below_Basic_Keystone_Biology', 
    'Keystone Biology: % of Students Proficient or Advanced, Grade 11': 'Percent_11th_Grade_Students_Proficient_Keystone_Biology', 
    'Keystone Literature: % of Students Below Basic, Grade 11': 'Percent_11th_Grade_Students_Below_Basic_Keystone_Literature', 
    'Keystone Literature: % of Students Proficient or Advanced, Grade 11': 'Percent_11th_Grade_Students_Proficient_Keystone_Literature', 
    '% of 12th Grade CTE Students Meeting Industry Standards': 'Percent_12th_Grade_CTE_Students_Meeting_Industry_Standards', 
    'Ninth-Grade On-Track Rate': 'Ninth_Grade_On_Track_Rate', 
    'Percent of Metrics Improving,  All Students': 'Percent_Metrics_Improving_All_Students', 
    '% of Students Attending at Least 90% of Instructional Days': 'Percent_Students_Attending_at_Least_90_Percent', 
    'Number of Dropouts - Last School of Touch (Grades 7-12)': 'Number_Dropouts_Grades_7_to_12', 
    '% of Students Receiving Zero Out-of-School Suspensions': 'Percent_Students_Receiving_Zero_Out_of_School_Suspensions', 
    '% of Students Completing the FAFSA by End of 12th Grade': 'Percent_Students_Completing_the_FAFSA_by_End_of_12th_Grade',
    'First-Fall Matriculation': 'First_Fall_Matriculation',
    'Four-Year Cohort Graduation Rate': 'Four_Year_Cohort_Graduation_Rate'
})

hs_metrics_df.head()
# Out:
# metric       Year  school_id                                  School_Name  \
# 0       2022-2023       1010                     John Bartram High School
# 1       2022-2023       1020                West Philadelphia High School
# 2       2022-2023       1030                    High School of the Future
# 3       2022-2023       1050  Paul Robeson High School for Human Services
# 4       2022-2023       1100                 William L. Sayre High School
#
# metric  Report_Type Admission_Type Number_Students_Served_Full_Year  \
# 0       High School      Catchment                              617
# 1       High School      Catchment                              608
# 2       High School       Citywide                              578
# 3       High School       Citywide                              341
# 4       High School      Catchment                              474
#
# metric October_1_Enrollment  \
# 0                       478
# 1                       545
# 2                       569
# 3                       313
# 4                       355
#
# metric Percent_11th_Grade_Students_Proficient_All_Three_Keystones  \
# 0                                                     4.2
# 1                                                       0
# 2                                                     4.8
# 3                                                    15.8
# 4                                                     1.7
#
# metric Percent_11th_Grade_Students_Below_Basic_Keystone_Algebra_I  \
# 0                                                    62.3
# 1                                                    54.1
# 2                                                    46.4
# 3                                                    21.1
# 4                                                    72.2
#
# metric Percent_11th_Grade_Students_Proficient_Keystone_Algebra_I  ...  \
# 0                                                     7.3         ...
# 1                                                     9.8         ...
# 2                                                     5.6         ...
# 3                                                    18.4         ...
# 4                                                     3.7         ...
#
# metric Percent_11th_Grade_Students_Proficient_Keystone_Literature  \
# 0                                                    17.2
# 1                                                      17
# 2                                                    30.4
# 3                                                    53.3
# 4                                                    16.4
#
# metric Percent_12th_Grade_CTE_Students_Meeting_Industry_Standards  \
# 0                                     Insufficient Sample
# 1                                                      20
# 2                                     Insufficient Sample
# 3                                     Insufficient Sample
# 4                                     Insufficient Sample
#
# metric Ninth_Grade_On_Track_Rate Percent_Metrics_Improving_All_Students  \
# 0                           71.1                                   58.3
# 1                           76.1                                   38.5
# 2                           62.9                                   58.3
# 3                           72.4                                     50
# 4                           87.7                                   33.3
#
# metric Percent_Students_Attending_at_Least_90_Percent  \
# 0                                                33.7
# 1                                                30.3
# 2                                                43.4
# 3                                                67.7
# 4                                                36.7
#
# metric Number_Dropouts_Grades_7_to_12  \
# 0                                  41
# 1                                  34
# 2                                  20
# 3                                   9
# 4                                  27
#
# metric Percent_Students_Receiving_Zero_Out_of_School_Suspensions  \
# 0                                                    80.6
# 1                                                    94.6
# 2                                                    90.7
# 3                                                    99.4
# 4                                                    81.2
#
# metric Percent_Students_Completing_the_FAFSA_by_End_of_12th_Grade  \
# 0                                                    30.7
# 1                                                    30.5
# 2                                                    44.9
# 3                                                    61.2
# 4                                                    19.3
#
# metric First_Fall_Matriculation Four_Year_Cohort_Graduation_Rate
# 0                          24.2                             70.5
# 1                          41.5                             82.1
# 2                          22.7                             92.4
# 3                          47.2                               96
# 4                          31.8                               63
#
# [5 rows x 23 columns]

# %%
hs_metrics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 23 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Year                                                         84 non-null     object
#  1   school_id                                                    84 non-null     int64
#  2   School_Name                                                  84 non-null     object
#  3   Report_Type                                                  84 non-null     object
#  4   Admission_Type                                               84 non-null     object
#  5   Number_Students_Served_Full_Year                             84 non-null     object
#  6   October_1_Enrollment                                         84 non-null     object
#  7   Percent_11th_Grade_Students_Proficient_All_Three_Keystones   84 non-null     object
#  8   Percent_11th_Grade_Students_Below_Basic_Keystone_Algebra_I   84 non-null     object
#  9   Percent_11th_Grade_Students_Proficient_Keystone_Algebra_I    84 non-null     object
#  10  Percent_11th_Grade_Students_Below_Basic_Keystone_Biology     84 non-null     object
#  11  Percent_11th_Grade_Students_Proficient_Keystone_Biology      84 non-null     object
#  12  Percent_11th_Grade_Students_Below_Basic_Keystone_Literature  84 non-null     object
#  13  Percent_11th_Grade_Students_Proficient_Keystone_Literature   84 non-null     object
#  14  Percent_12th_Grade_CTE_Students_Meeting_Industry_Standards   84 non-null     object
#  15  Ninth_Grade_On_Track_Rate                                    84 non-null     object
#  16  Percent_Metrics_Improving_All_Students                       84 non-null     object
#  17  Percent_Students_Attending_at_Least_90_Percent               84 non-null     object
#  18  Number_Dropouts_Grades_7_to_12                               84 non-null     object
#  19  Percent_Students_Receiving_Zero_Out_of_School_Suspensions    84 non-null     object
#  20  Percent_Students_Completing_the_FAFSA_by_End_of_12th_Grade   84 non-null     object
#  21  First_Fall_Matriculation                                     84 non-null     object
#  22  Four_Year_Cohort_Graduation_Rate                             84 non-null     object
# dtypes: int64(1), object(22)
# memory usage: 15.2+ KB

# %%
# List the hs_metrics_df columns
# hs_metrics_df.columns

# %%
# List of columns to convert
hs_columns_to_convert = [
    'Number_Students_Served_Full_Year', 
    'October_1_Enrollment',
    'Percent_11th_Grade_Students_Proficient_All_Three_Keystones',
    'Percent_11th_Grade_Students_Below_Basic_Keystone_Algebra_I',
    'Percent_11th_Grade_Students_Proficient_Keystone_Algebra_I',
    'Percent_11th_Grade_Students_Below_Basic_Keystone_Biology',
    'Percent_11th_Grade_Students_Proficient_Keystone_Biology',
    'Percent_11th_Grade_Students_Below_Basic_Keystone_Literature',
    'Percent_11th_Grade_Students_Proficient_Keystone_Literature',
    'Percent_12th_Grade_CTE_Students_Meeting_Industry_Standards',
    'Ninth_Grade_On_Track_Rate', 
    'Percent_Metrics_Improving_All_Students',
    'Percent_Students_Attending_at_Least_90_Percent',
    'Number_Dropouts_Grades_7_to_12',
    'Percent_Students_Receiving_Zero_Out_of_School_Suspensions',
    'Percent_Students_Completing_the_FAFSA_by_End_of_12th_Grade',
    'First_Fall_Matriculation', 
    'Four_Year_Cohort_Graduation_Rate'
]

# Apply pd.to_numeric to convert strings to 'NaN'
hs_metrics_df[hs_columns_to_convert] = hs_metrics_df[hs_columns_to_convert].apply(lambda x: pd.to_numeric(x, errors='coerce'))

# Set the datatypes
hs_metrics_df = hs_metrics_df.astype({    
    'Number_Students_Served_Full_Year': 'int64', 
    'October_1_Enrollment': 'int64',
    'Percent_11th_Grade_Students_Proficient_All_Three_Keystones': 'float64',
    'Percent_11th_Grade_Students_Below_Basic_Keystone_Algebra_I': 'float64',
    'Percent_11th_Grade_Students_Proficient_Keystone_Algebra_I': 'float64',
    'Percent_11th_Grade_Students_Below_Basic_Keystone_Biology': 'float64',
    'Percent_11th_Grade_Students_Proficient_Keystone_Biology': 'float64',
    'Percent_11th_Grade_Students_Below_Basic_Keystone_Literature': 'float64',
    'Percent_11th_Grade_Students_Proficient_Keystone_Literature': 'float64',
    'Percent_12th_Grade_CTE_Students_Meeting_Industry_Standards': 'float64',
    'Ninth_Grade_On_Track_Rate': 'float64', 
    'Percent_Metrics_Improving_All_Students': 'float64',
    'Percent_Students_Attending_at_Least_90_Percent': 'float64',
    'Number_Dropouts_Grades_7_to_12': 'int64',
    'Percent_Students_Receiving_Zero_Out_of_School_Suspensions': 'float64',
    'Percent_Students_Completing_the_FAFSA_by_End_of_12th_Grade': 'float64',
    'First_Fall_Matriculation': 'float64', 
    'Four_Year_Cohort_Graduation_Rate': 'float64'
})

# %%
hs_metrics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 23 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Year                                                         84 non-null     object
#  1   school_id                                                    84 non-null     int64
#  2   School_Name                                                  84 non-null     object
#  3   Report_Type                                                  84 non-null     object
#  4   Admission_Type                                               84 non-null     object
#  5   Number_Students_Served_Full_Year                             84 non-null     int64
#  6   October_1_Enrollment                                         84 non-null     int64
#  7   Percent_11th_Grade_Students_Proficient_All_Three_Keystones   84 non-null     float64
#  8   Percent_11th_Grade_Students_Below_Basic_Keystone_Algebra_I   83 non-null     float64
#  9   Percent_11th_Grade_Students_Proficient_Keystone_Algebra_I    83 non-null     float64
#  10  Percent_11th_Grade_Students_Below_Basic_Keystone_Biology     82 non-null     float64
#  11  Percent_11th_Grade_Students_Proficient_Keystone_Biology      82 non-null     float64
#  12  Percent_11th_Grade_Students_Below_Basic_Keystone_Literature  84 non-null     float64
#  13  Percent_11th_Grade_Students_Proficient_Keystone_Literature   84 non-null     float64
#  14  Percent_12th_Grade_CTE_Students_Meeting_Industry_Standards   21 non-null     float64
#  15  Ninth_Grade_On_Track_Rate                                    83 non-null     float64
#  16  Percent_Metrics_Improving_All_Students                       81 non-null     float64
#  17  Percent_Students_Attending_at_Least_90_Percent               84 non-null     float64
#  18  Number_Dropouts_Grades_7_to_12                               84 non-null     int64
#  19  Percent_Students_Receiving_Zero_Out_of_School_Suspensions    84 non-null     float64
#  20  Percent_Students_Completing_the_FAFSA_by_End_of_12th_Grade   84 non-null     float64
#  21  First_Fall_Matriculation                                     82 non-null     float64
#  22  Four_Year_Cohort_Graduation_Rate                             84 non-null     float64
# dtypes: float64(15), int64(4), object(4)
# memory usage: 15.2+ KB

# %%
# Export to csv 
hs_metrics_df.to_csv('Outputs_School_Metrics/high_school_metric_scores.csv', index=False)

# %%
middle_school_metrics_df.head()
# Out:
#      accountability_year  school_id               school_name    report_type  \
# 1300           2022-2023       1130  William T. Tilden School  Middle School
# 1304           2022-2023       1130  William T. Tilden School  Middle School
# 1307           2022-2023       1130  William T. Tilden School  Middle School
# 1308           2022-2023       1130  William T. Tilden School  Middle School
# 1309           2022-2023       1130  William T. Tilden School  Middle School
#
#                                                  metric  numerator  \
# 1300                                     Admission Type        NaN
# 1304  % of Students Attending at Least 90% of Instru...      280.0
# 1307  Number of Dropouts - Last School of Touch (Gra...        NaN
# 1308            # of Students Served Over the Full Year        NaN
# 1309                               October 1 Enrollment        NaN
#
#       denominator metric_score score_previous    score_change           tier
# 1300          NaN    Catchment   Neighborhood  Not Applicable            NaN
# 1304        404.0         69.3           50.5            18.8      Improving
# 1307          NaN            4              3               1  Not Improving
# 1308          NaN          404            438             -34            NaN
# 1309          NaN          329            346             -17            NaN

# %%
# Pivot the middle_school_metrics_df DataFrame to create one row for each school 
ms_metrics_df = middle_school_metrics_df.pivot_table(
    index = ['accountability_year', 'school_id', 'school_name', 'report_type'],
    columns = 'metric', 
    values = 'metric_score',
    aggfunc='first'
).reset_index()

ms_metrics_df.head()
# Out:
# metric accountability_year  school_id  \
# 0                2022-2023       1130
# 1                2022-2023       1580
# 2                2022-2023       2050
# 3                2022-2023       2140
# 4                2022-2023       2410
#
# metric                               school_name    report_type  \
# 0                       William T. Tilden School  Middle School
# 1                Middle Years Alternative School  Middle School
# 2       Science Leadership Academy Middle School  Middle School
# 3                      Julia R. Masterman School  Middle School
# 4                  Girard Academic Music Program  Middle School
#
# metric # of Students Served Over the Full Year  \
# 0                                          404
# 1                                          179
# 2                                          379
# 3                                          735
# 4                                          332
#
# metric % of Students Attending at Least 90% of Instructional Days  \
# 0                                                    69.3
# 1                                                    74.3
# 2                                                      95
# 3                                                    94.8
# 4                                                    95.5
#
# metric % of Students Receiving Zero Out-of-School Suspensions  \
# 0                                                    92.6
# 1                                                    91.1
# 2                                                    95.8
# 3                                                    97.6
# 4                                                    96.1
#
# metric % of Teachers Attending at Least 90% of Instructional Days  \
# 0                                                      71
# 1                                                    93.3
# 2                                                      95
# 3                                                    86.4
# 4                                                    87.9
#
# metric % of Teachers Rated as Distinguished % of Teachers Rated as Proficient  \
# 0                                         0                               100
# 1                                        20                                80
# 2                                         0                              94.1
# 3                                      70.8                              29.2
# 4                                        36                                64
#
# metric  ... Number of Dropouts - Last School of Touch (Grades 7-12)  \
# 0       ...                                                  4
# 1       ...                                                  2
# 2       ...                                                  1
# 3       ...                                                  1
# 4       ...                                                  2
#
# metric October 1 Enrollment PSSA ELA: % of Students Below Basic, Grades 3-8  \
# 0                       329                                            39.2
# 1                       171                                            12.1
# 2                       358                                            12.3
# 3                       716                                             0.6
# 4                       330                                             0.9
#
# metric PSSA ELA: % of Students Proficient or Advanced, Grades 3-8  \
# 0                                                    16.5
# 1                                                      38
# 2                                                      56
# 3                                                      94
# 4                                                    92.2
#
# metric PSSA Math: % of Students Below Basic, Grades 3-8  \
# 0                                                  85.6
# 1                                                  55.2
# 2                                                  55.6
# 3                                                   5.6
# 4                                                   6.9
#
# metric PSSA Math: % of Students Proficient or Advanced, Grades 3-8  \
# 0                                                     3.5
# 1                                                    14.6
# 2                                                      21
# 3                                                    81.9
# 4                                                    72.9
#
# metric PSSA Science: % of Students Below Basic, Grades 4-8  \
# 0                                                    63.6
# 1                                                      29
# 2                                                    35.4
# 3                                                       0
# 4                                                     2.4
#
# metric PSSA Science: % of Students Proficient or Advanced, Grades 4-8  \
# 0                                                    16.2
# 1                                                    41.9
# 2                                                    48.1
# 3                                                    98.9
# 4                                                    90.6
#
# metric Percent of Metrics Improving,  All Students  \
# 0                                               50
# 1                                               60
# 2                                               60
# 3                                               20
# 4                                               50
#
# metric Year-to-Year Teacher Retention
# 0                                62.1
# 1                                  75
# 2                                  80
# 3                                83.1
# 4                                94.1
#
# [5 rows x 21 columns]

# %%
# List the ms_metrics_df columns
# ms_metrics_df.columns

# %%
# Create a list with desireds column order
ms_columns = [
    'accountability_year', 
    'school_id', 
    'school_name', 
    'report_type', 
    'Admission Type', 
    '# of Students Served Over the Full Year', 
    'October 1 Enrollment', 
    'PSSA ELA: % of Students Below Basic, Grades 3-8',
    'PSSA ELA: % of Students Proficient or Advanced, Grades 3-8',
    'PSSA Math: % of Students Below Basic, Grades 3-8',
    'PSSA Math: % of Students Proficient or Advanced, Grades 3-8',
    'PSSA Science: % of Students Below Basic, Grades 4-8',
    'PSSA Science: % of Students Proficient or Advanced, Grades 4-8',
    'Percent of Metrics Improving,  All Students', 
    '% of Students Attending at Least 90% of Instructional Days', 
    'Number of Dropouts - Last School of Touch (Grades 7-12)',
    '% of Students Receiving Zero Out-of-School Suspensions'
]

# Reorder the DataFrame columns
ms_metrics_df = ms_metrics_df[ms_columns]

# %%
# Rename the Columns with compatible formatting 
ms_metrics_df = ms_metrics_df.rename(columns={
    'accountability_year': 'Year', 
    'school_id': 'school_id', 
    'school_name': 'School_Name', 
    'report_type': 'Report_Type', 
    'Admission Type': 'Admission_Type', 
    '# of Students Served Over the Full Year': 'Number_Students_Served_Full_Year', 
    'October 1 Enrollment': 'October_1_Enrollment', 
    'PSSA ELA: % of Students Below Basic, Grades 3-8': 'PSSA_ELA_Percent_Students_Below_Basic_Grades_3_to_8',
    'PSSA ELA: % of Students Proficient or Advanced, Grades 3-8': 'PSSA_ELA_Percent_Students_Proficient_or_Advanced_Grades_3_to_8',
    'PSSA Math: % of Students Below Basic, Grades 3-8': 'PSSA_Math_Percent_Students_Below_Basic_Grades_3_to_8',
    'PSSA Math: % of Students Proficient or Advanced, Grades 3-8': 'PSSA_Math_Percent_Students_Proficient_or_Advanced_Grades_3_to_8',
    'PSSA Science: % of Students Below Basic, Grades 4-8': 'PSSA_Science_Percent_Students_Below_Basic_Grades_4_to_8',
    'PSSA Science: % of Students Proficient or Advanced, Grades 4-8': 'PSSA_Science_Percent_Students_Proficient_or_Advanced_Grades_4_to_8',
    'Percent of Metrics Improving,  All Students': 'Percent_Metrics_Improving_All_Students', 
    '% of Students Attending at Least 90% of Instructional Days': 'Percent_Students_Attending_at_Least_90_Percent', 
    'Number of Dropouts - Last School of Touch (Grades 7-12)': 'Number_Dropouts_Grades_7_to_12',
    '% of Students Receiving Zero Out-of-School Suspensions': 'Percent_Students_Receiving_Zero_Out_of_School_Suspensions'
})
ms_metrics_df.head()
# Out:
# metric       Year  school_id                               School_Name  \
# 0       2022-2023       1130                  William T. Tilden School
# 1       2022-2023       1580           Middle Years Alternative School
# 2       2022-2023       2050  Science Leadership Academy Middle School
# 3       2022-2023       2140                 Julia R. Masterman School
# 4       2022-2023       2410             Girard Academic Music Program
#
# metric    Report_Type  Admission_Type Number_Students_Served_Full_Year  \
# 0       Middle School       Catchment                              404
# 1       Middle School        Citywide                              179
# 2       Middle School       Catchment                              379
# 3       Middle School  Criteria-Based                              735
# 4       Middle School  Criteria-Based                              332
#
# metric October_1_Enrollment  \
# 0                       329
# 1                       171
# 2                       358
# 3                       716
# 4                       330
#
# metric PSSA_ELA_Percent_Students_Below_Basic_Grades_3_to_8  \
# 0                                                    39.2
# 1                                                    12.1
# 2                                                    12.3
# 3                                                     0.6
# 4                                                     0.9
#
# metric PSSA_ELA_Percent_Students_Proficient_or_Advanced_Grades_3_to_8  \
# 0                                                    16.5
# 1                                                      38
# 2                                                      56
# 3                                                      94
# 4                                                    92.2
#
# metric PSSA_Math_Percent_Students_Below_Basic_Grades_3_to_8  \
# 0                                                    85.6
# 1                                                    55.2
# 2                                                    55.6
# 3                                                     5.6
# 4                                                     6.9
#
# metric PSSA_Math_Percent_Students_Proficient_or_Advanced_Grades_3_to_8  \
# 0                                                     3.5
# 1                                                    14.6
# 2                                                      21
# 3                                                    81.9
# 4                                                    72.9
#
# metric PSSA_Science_Percent_Students_Below_Basic_Grades_4_to_8  \
# 0                                                    63.6
# 1                                                      29
# 2                                                    35.4
# 3                                                       0
# 4                                                     2.4
#
# metric PSSA_Science_Percent_Students_Proficient_or_Advanced_Grades_4_to_8  \
# 0                                                    16.2
# 1                                                    41.9
# 2                                                    48.1
# 3                                                    98.9
# 4                                                    90.6
#
# metric Percent_Metrics_Improving_All_Students  \
# 0                                          50
# 1                                          60
# 2                                          60
# 3                                          20
# 4                                          50
#
# metric Percent_Students_Attending_at_Least_90_Percent  \
# 0                                                69.3
# 1                                                74.3
# 2                                                  95
# 3                                                94.8
# 4                                                95.5
#
# metric Number_Dropouts_Grades_7_to_12  \
# 0                                   4
# 1                                   2
# 2                                   1
# 3                                   1
# 4                                   2
#
# metric Percent_Students_Receiving_Zero_Out_of_School_Suspensions
# 0                                                    92.6
# 1                                                    91.1
# 2                                                    95.8
# 3                                                    97.6
# 4                                                    96.1

# %%
ms_metrics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 17 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Year                                                                29 non-null     object
#  1   school_id                                                           29 non-null     int64
#  2   School_Name                                                         29 non-null     object
#  3   Report_Type                                                         29 non-null     object
#  4   Admission_Type                                                      29 non-null     object
#  5   Number_Students_Served_Full_Year                                    29 non-null     object
#  6   October_1_Enrollment                                                29 non-null     object
#  7   PSSA_ELA_Percent_Students_Below_Basic_Grades_3_to_8                 29 non-null     object
#  8   PSSA_ELA_Percent_Students_Proficient_or_Advanced_Grades_3_to_8      29 non-null     object
#  9   PSSA_Math_Percent_Students_Below_Basic_Grades_3_to_8                29 non-null     object
#  10  PSSA_Math_Percent_Students_Proficient_or_Advanced_Grades_3_to_8     29 non-null     object
#  11  PSSA_Science_Percent_Students_Below_Basic_Grades_4_to_8             29 non-null     object
#  12  PSSA_Science_Percent_Students_Proficient_or_Advanced_Grades_4_to_8  29 non-null     object
#  13  Percent_Metrics_Improving_All_Students                              29 non-null     object
#  14  Percent_Students_Attending_at_Least_90_Percent                      29 non-null     object
#  15  Number_Dropouts_Grades_7_to_12                                      29 non-null     object
#  16  Percent_Students_Receiving_Zero_Out_of_School_Suspensions           29 non-null     object
# dtypes: int64(1), object(16)
# memory usage: 4.0+ KB

# %%
# List the ms_metrics_df columns
# ms_metrics_df.columns

# %%
# List of columns to convert
ms_columns_to_convert = [
    'Number_Students_Served_Full_Year', 
    'October_1_Enrollment',
    'PSSA_ELA_Percent_Students_Below_Basic_Grades_3_to_8',
    'PSSA_ELA_Percent_Students_Proficient_or_Advanced_Grades_3_to_8',
    'PSSA_Math_Percent_Students_Below_Basic_Grades_3_to_8',
    'PSSA_Math_Percent_Students_Proficient_or_Advanced_Grades_3_to_8',
    'PSSA_Science_Percent_Students_Below_Basic_Grades_4_to_8',
    'PSSA_Science_Percent_Students_Proficient_or_Advanced_Grades_4_to_8',
    'Percent_Metrics_Improving_All_Students',
    'Percent_Students_Attending_at_Least_90_Percent',
    'Number_Dropouts_Grades_7_to_12',
    'Percent_Students_Receiving_Zero_Out_of_School_Suspensions'
]

# Apply pd.to_numeric to convert strings to 'NaN'
ms_metrics_df[ms_columns_to_convert] = ms_metrics_df[ms_columns_to_convert].apply(lambda x: pd.to_numeric(x, errors='coerce'))

# Set the datatypes
ms_metrics_df = ms_metrics_df.astype({    
    'Number_Students_Served_Full_Year': 'int64', 
    'October_1_Enrollment': 'int64',
    'PSSA_ELA_Percent_Students_Below_Basic_Grades_3_to_8': 'float64',
    'PSSA_ELA_Percent_Students_Proficient_or_Advanced_Grades_3_to_8': 'float64',
    'PSSA_Math_Percent_Students_Below_Basic_Grades_3_to_8': 'float64',
    'PSSA_Math_Percent_Students_Proficient_or_Advanced_Grades_3_to_8': 'float64',
    'PSSA_Science_Percent_Students_Below_Basic_Grades_4_to_8': 'float64',
    'PSSA_Science_Percent_Students_Proficient_or_Advanced_Grades_4_to_8': 'float64',
    'Percent_Metrics_Improving_All_Students': 'float64',
    'Percent_Students_Attending_at_Least_90_Percent': 'float64',
    'Number_Dropouts_Grades_7_to_12': 'int64',
    'Percent_Students_Receiving_Zero_Out_of_School_Suspensions': 'float64'
})

# %%
ms_metrics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 17 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Year                                                                29 non-null     object
#  1   school_id                                                           29 non-null     int64
#  2   School_Name                                                         29 non-null     object
#  3   Report_Type                                                         29 non-null     object
#  4   Admission_Type                                                      29 non-null     object
#  5   Number_Students_Served_Full_Year                                    29 non-null     int64
#  6   October_1_Enrollment                                                29 non-null     int64
#  7   PSSA_ELA_Percent_Students_Below_Basic_Grades_3_to_8                 29 non-null     float64
#  8   PSSA_ELA_Percent_Students_Proficient_or_Advanced_Grades_3_to_8      29 non-null     float64
#  9   PSSA_Math_Percent_Students_Below_Basic_Grades_3_to_8                29 non-null     float64
#  10  PSSA_Math_Percent_Students_Proficient_or_Advanced_Grades_3_to_8     29 non-null     float64
#  11  PSSA_Science_Percent_Students_Below_Basic_Grades_4_to_8             29 non-null     float64
#  12  PSSA_Science_Percent_Students_Proficient_or_Advanced_Grades_4_to_8  29 non-null     float64
#  13  Percent_Metrics_Improving_All_Students                              28 non-null     float64
#  14  Percent_Students_Attending_at_Least_90_Percent                      29 non-null     float64
#  15  Number_Dropouts_Grades_7_to_12                                      29 non-null     int64
#  16  Percent_Students_Receiving_Zero_Out_of_School_Suspensions           29 non-null     float64
# dtypes: float64(9), int64(4), object(4)
# memory usage: 4.0+ KB

# %%
# Export to csv 
ms_metrics_df.to_csv('Outputs_School_Metrics/middle_school_metric_scores.csv', index=False)

# %%
ktoeight_school_metrics_df.head()
# Out:
#      accountability_year  school_id        school_name report_type  \
# 1820           2022-2023       1200  John Barry School  K-8 School
# 1824           2022-2023       1200  John Barry School  K-8 School
# 1827           2022-2023       1200  John Barry School  K-8 School
# 1828           2022-2023       1200  John Barry School  K-8 School
# 1829           2022-2023       1200  John Barry School  K-8 School
#
#                                                  metric  numerator  \
# 1820                                     Admission Type        NaN
# 1824  % of Students Attending at Least 90% of Instru...      226.0
# 1827  Number of Dropouts - Last School of Touch (Gra...        NaN
# 1828            # of Students Served Over the Full Year        NaN
# 1829                               October 1 Enrollment        NaN
#
#       denominator metric_score score_previous    score_change       tier
# 1820          NaN    Catchment   Neighborhood  Not Applicable        NaN
# 1824        602.0         37.5             27            10.5  Improving
# 1827          NaN            3             11              -8  Improving
# 1828          NaN          602            549              53        NaN
# 1829          NaN          500            475              25        NaN

# %%
# Pivot the ktoeight_school_metrics_df DataFrame to create one row for each school 
ktes_metrics_df = ktoeight_school_metrics_df.pivot_table(
    index = ['accountability_year', 'school_id', 'school_name', 'report_type'],
    columns = 'metric', 
    values = 'metric_score',
    aggfunc='first'
).reset_index()

ktes_metrics_df.head()
# Out:
# metric accountability_year  school_id                 school_name report_type  \
# 0                2022-2023       1200           John Barry School  K-8 School
# 1                2022-2023       1230    William C. Bryant School  K-8 School
# 2                2022-2023       1260  Benjamin B. Comegys School  K-8 School
# 3                2022-2023       1280      Sadie Alexander School  K-8 School
# 4                2022-2023       1290      Andrew Hamilton School  K-8 School
#
# metric # of Students Served Over the Full Year  \
# 0                                          602
# 1                                          407
# 2                                          365
# 3                                          586
# 4                                          406
#
# metric % of Students Attending at Least 90% of Instructional Days  \
# 0                                                    37.5
# 1                                                    44.2
# 2                                                    33.7
# 3                                                    96.6
# 4                                                    45.1
#
# metric % of Students Receiving Zero Out-of-School Suspensions  \
# 0                                                    96.8
# 1                                                    91.4
# 2                                                    85.2
# 3                                                     100
# 4                                                    94.8
#
# metric % of Teachers Attending at Least 90% of Instructional Days  \
# 0                                                    71.4
# 1                                                      71
# 2                                                    55.6
# 3                                                    92.7
# 4                                                    86.7
#
# metric % of Teachers Rated as Distinguished % of Teachers Rated as Proficient  \
# 0                                      14.3                              78.6
# 1                                       7.7                              92.3
# 2                                         0                              87.5
# 3                                      73.7                              26.3
# 4                                         0                                76
#
# metric  ... PSSA ELA: % of Students Proficient or Advanced, Grade 3  \
# 0       ...                                                 10
# 1       ...                                               21.2
# 2       ...                                               13.3
# 3       ...                                               83.3
# 4       ...                                               14.8
#
# metric PSSA ELA: % of Students Proficient or Advanced, Grades 3-8  \
# 0                                                      14
# 1                                                    16.6
# 2                                                    16.8
# 3                                                    85.4
# 4                                                    16.9
#
# metric PSSA Math: % of Students Below Basic, Grade 3  \
# 0                                               79.1
# 1                                               61.3
# 2                                               62.1
# 3                                                6.9
# 4                                               77.8
#
# metric PSSA Math: % of Students Below Basic, Grades 3-8  \
# 0                                                  81.4
# 1                                                  74.2
# 2                                                  76.7
# 3                                                   8.9
# 4                                                  78.8
#
# metric PSSA Math: % of Students Proficient or Advanced, Grade 3  \
# 0                                                     4.7
# 1                                                     6.5
# 2                                                    10.3
# 3                                                    81.9
# 4                                                     7.4
#
# metric PSSA Math: % of Students Proficient or Advanced, Grades 3-8  \
# 0                                                     4.1
# 1                                                     2.2
# 2                                                     5.2
# 3                                                    77.1
# 4                                                     3.3
#
# metric PSSA Science: % of Students Below Basic, Grades 4-8  \
# 0                                                    42.9
# 1                                                      50
# 2                                                    38.2
# 3                                                     6.7
# 4                                                    36.1
#
# metric PSSA Science: % of Students Proficient or Advanced, Grades 4-8  \
# 0                                                    21.4
# 1                                                      20
# 2                                                    25.5
# 3                                                    89.2
# 4                                                    30.2
#
# metric Percent of Metrics Improving,  All Students  \
# 0                                             64.3
# 1                                             85.7
# 2                                             57.1
# 3                                             57.1
# 4                                             85.7
#
# metric Year-to-Year Teacher Retention
# 0                                  79
# 1                                33.3
# 2                                60.7
# 3                                  90
# 4                                83.9
#
# [5 rows x 25 columns]

# %%
# List the ktes_metrics_df columns
ktes_metrics_df.columns
# Out:
# Index(['accountability_year', 'school_id', 'school_name', 'report_type',
#        '# of Students Served Over the Full Year',
#        '% of Students Attending at Least 90% of Instructional Days',
#        '% of Students Receiving Zero Out-of-School Suspensions',
#        '% of Teachers Attending at Least 90% of Instructional Days',
#        '% of Teachers Rated as Distinguished',
#        '% of Teachers Rated as Proficient', 'Admission Type',
#        'Number of Dropouts - Last School of Touch (Grades 7-12)',
#        'October 1 Enrollment', 'PSSA ELA: % of Students Below Basic, Grade 3',
#        'PSSA ELA: % of Students Below Basic, Grades 3-8',
#        'PSSA ELA: % of Students Proficient or Advanced, Grade 3',
#        'PSSA ELA: % of Students Proficient or Advanced, Grades 3-8',
#        'PSSA Math: % of Students Below Basic, Grade 3',
#        'PSSA Math: % of Students Below Basic, Grades 3-8',
#        'PSSA Math: % of Students Proficient or Advanced, Grade 3',
#        'PSSA Math: % of Students Proficient or Advanced, Grades 3-8',
#        'PSSA Science: % of Students Below Basic, Grades 4-8',
#        'PSSA Science: % of Students Proficient or Advanced, Grades 4-8',
#        'Percent of Metrics Improving,  All Students',
#        'Year-to-Year Teacher Retention'],
#       dtype='object', name='metric')

# %%
# Create a list with desireds column order
ktes_columns = [
    'accountability_year', 
    'school_id', 
    'school_name', 
    'report_type', 
    'Admission Type', 
    '# of Students Served Over the Full Year', 
    'October 1 Enrollment', 
    'PSSA ELA: % of Students Below Basic, Grade 3',
    'PSSA ELA: % of Students Below Basic, Grades 3-8',
    'PSSA ELA: % of Students Proficient or Advanced, Grade 3',
    'PSSA ELA: % of Students Proficient or Advanced, Grades 3-8',
    'PSSA Math: % of Students Below Basic, Grade 3',
    'PSSA Math: % of Students Below Basic, Grades 3-8',
    'PSSA Math: % of Students Proficient or Advanced, Grade 3',
    'PSSA Math: % of Students Proficient or Advanced, Grades 3-8',
    'PSSA Science: % of Students Below Basic, Grades 4-8',
    'PSSA Science: % of Students Proficient or Advanced, Grades 4-8',
    'Percent of Metrics Improving,  All Students', 
    '% of Students Attending at Least 90% of Instructional Days', 
    'Number of Dropouts - Last School of Touch (Grades 7-12)',
    '% of Students Receiving Zero Out-of-School Suspensions'
]
# Reorder the DataFrame columns
ktes_metrics_df = ktes_metrics_df[ktes_columns]

# %%
# Rename the Columns with compatible formatting 
ktes_metrics_df = ktes_metrics_df.rename(columns={
    'accountability_year': 'Year', 
    'school_id': 'school_id', 
    'school_name': 'School_Name', 
    'report_type': 'Report_Type', 
    'Admission Type': 'Admission_Type', 
    '# of Students Served Over the Full Year': 'Number_Students_Served_Full_Year', 
    'October 1 Enrollment': 'October_1_Enrollment', 
    'PSSA ELA: % of Students Below Basic, Grade 3': 'PSSA_ELA_Percent_Students_Below_Basic_Grade_3',
    'PSSA ELA: % of Students Below Basic, Grades 3-8': 'PSSA_ELA_Percent_Students_Below_Basic_Grades_3_to_8',
    'PSSA ELA: % of Students Proficient or Advanced, Grade 3': 'PSSA_ELA_Percent_Students_Proficient_or_Advanced_Grade_3',
    'PSSA ELA: % of Students Proficient or Advanced, Grades 3-8': 'PSSA_ELA_Percent_Students_Proficient_or_Advanced_Grades_3_to_8',
    'PSSA Math: % of Students Below Basic, Grade 3': 'PSSA_Math_Percent_Students_Below_Basic_Grade_3',
    'PSSA Math: % of Students Below Basic, Grades 3-8': 'PSSA_Math_Percent_Students_Below_Basic_Grades_3_to_8',
    'PSSA Math: % of Students Proficient or Advanced, Grade 3': 'PSSA_Math_Percent_Students_Proficient_or_Advanced_Grade_3',
    'PSSA Math: % of Students Proficient or Advanced, Grades 3-8': 'PSSA_Math_Percent_Students_Proficient_or_Advanced_Grades_3_to_8',
    'PSSA Science: % of Students Below Basic, Grades 4-8': 'PSSA_Science_Percent_Students_Below_Basic_Grades_4_to_8',
    'PSSA Science: % of Students Proficient or Advanced, Grades 4-8': 'PSSA_Science_Percent_Students_Proficient_or_Advanced_Grades_4_to_8',
    'Percent of Metrics Improving,  All Students': 'Percent_Metrics_Improving_All_Students', 
    '% of Students Attending at Least 90% of Instructional Days': 'Percent_Students_Attending_at_Least_90_Percent', 
    'Number of Dropouts - Last School of Touch (Grades 7-12)': 'Number_Dropouts_Grades_7_to_12',
    '% of Students Receiving Zero Out-of-School Suspensions': 'Percent_Students_Receiving_Zero_Out_of_School_Suspensions'
})

ktes_metrics_df.head()
# Out:
# metric       Year  school_id                 School_Name Report_Type  \
# 0       2022-2023       1200           John Barry School  K-8 School
# 1       2022-2023       1230    William C. Bryant School  K-8 School
# 2       2022-2023       1260  Benjamin B. Comegys School  K-8 School
# 3       2022-2023       1280      Sadie Alexander School  K-8 School
# 4       2022-2023       1290      Andrew Hamilton School  K-8 School
#
# metric Admission_Type Number_Students_Served_Full_Year October_1_Enrollment  \
# 0           Catchment                              602                  500
# 1           Catchment                              407                  329
# 2           Catchment                              365                  319
# 3           Catchment                              586                  578
# 4           Catchment                              406                  347
#
# metric PSSA_ELA_Percent_Students_Below_Basic_Grade_3  \
# 0                                                 58
# 1                                               27.3
# 2                                                 30
# 3                                                5.6
# 4                                               33.3
#
# metric PSSA_ELA_Percent_Students_Below_Basic_Grades_3_to_8  \
# 0                                                    43.5
# 1                                                    28.7
# 2                                                    28.9
# 3                                                     2.9
# 4                                                    33.8
#
# metric PSSA_ELA_Percent_Students_Proficient_or_Advanced_Grade_3  ...  \
# 0                                                      10        ...
# 1                                                    21.2        ...
# 2                                                    13.3        ...
# 3                                                    83.3        ...
# 4                                                    14.8        ...
#
# metric PSSA_Math_Percent_Students_Below_Basic_Grade_3  \
# 0                                                79.1
# 1                                                61.3
# 2                                                62.1
# 3                                                 6.9
# 4                                                77.8
#
# metric PSSA_Math_Percent_Students_Below_Basic_Grades_3_to_8  \
# 0                                                    81.4
# 1                                                    74.2
# 2                                                    76.7
# 3                                                     8.9
# 4                                                    78.8
#
# metric PSSA_Math_Percent_Students_Proficient_or_Advanced_Grade_3  \
# 0                                                     4.7
# 1                                                     6.5
# 2                                                    10.3
# 3                                                    81.9
# 4                                                     7.4
#
# metric PSSA_Math_Percent_Students_Proficient_or_Advanced_Grades_3_to_8  \
# 0                                                     4.1
# 1                                                     2.2
# 2                                                     5.2
# 3                                                    77.1
# 4                                                     3.3
#
# metric PSSA_Science_Percent_Students_Below_Basic_Grades_4_to_8  \
# 0                                                    42.9
# 1                                                      50
# 2                                                    38.2
# 3                                                     6.7
# 4                                                    36.1
#
# metric PSSA_Science_Percent_Students_Proficient_or_Advanced_Grades_4_to_8  \
# 0                                                    21.4
# 1                                                      20
# 2                                                    25.5
# 3                                                    89.2
# 4                                                    30.2
#
# metric Percent_Metrics_Improving_All_Students  \
# 0                                        64.3
# 1                                        85.7
# 2                                        57.1
# 3                                        57.1
# 4                                        85.7
#
# metric Percent_Students_Attending_at_Least_90_Percent  \
# 0                                                37.5
# 1                                                44.2
# 2                                                33.7
# 3                                                96.6
# 4                                                45.1
#
# metric Number_Dropouts_Grades_7_to_12  \
# 0                                   3
# 1                                   3
# 2                                   1
# 3                                   0
# 4                                   0
#
# metric Percent_Students_Receiving_Zero_Out_of_School_Suspensions
# 0                                                    96.8
# 1                                                    91.4
# 2                                                    85.2
# 3                                                     100
# 4                                                    94.8
#
# [5 rows x 21 columns]

# %%
ktes_metrics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154 entries, 0 to 153
# Data columns (total 21 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Year                                                                154 non-null    object
#  1   school_id                                                           154 non-null    int64
#  2   School_Name                                                         154 non-null    object
#  3   Report_Type                                                         154 non-null    object
#  4   Admission_Type                                                      154 non-null    object
#  5   Number_Students_Served_Full_Year                                    154 non-null    object
#  6   October_1_Enrollment                                                154 non-null    object
#  7   PSSA_ELA_Percent_Students_Below_Basic_Grade_3                       154 non-null    object
#  8   PSSA_ELA_Percent_Students_Below_Basic_Grades_3_to_8                 154 non-null    object
#  9   PSSA_ELA_Percent_Students_Proficient_or_Advanced_Grade_3            154 non-null    object
#  10  PSSA_ELA_Percent_Students_Proficient_or_Advanced_Grades_3_to_8      154 non-null    object
#  11  PSSA_Math_Percent_Students_Below_Basic_Grade_3                      154 non-null    object
#  12  PSSA_Math_Percent_Students_Below_Basic_Grades_3_to_8                154 non-null    object
#  13  PSSA_Math_Percent_Students_Proficient_or_Advanced_Grade_3           154 non-null    object
#  14  PSSA_Math_Percent_Students_Proficient_or_Advanced_Grades_3_to_8     154 non-null    object
#  15  PSSA_Science_Percent_Students_Below_Basic_Grades_4_to_8             154 non-null    object
#  16  PSSA_Science_Percent_Students_Proficient_or_Advanced_Grades_4_to_8  154 non-null    object
#  17  Percent_Metrics_Improving_All_Students                              154 non-null    object
#  18  Percent_Students_Attending_at_Least_90_Percent                      154 non-null    object
#  19  Number_Dropouts_Grades_7_to_12                                      154 non-null    object
#  20  Percent_Students_Receiving_Zero_Out_of_School_Suspensions           154 non-null    object
# dtypes: int64(1), object(20)
# memory usage: 25.4+ KB

# %%
# List the ms_metrics_df columns
# ktes_metrics_df.columns

# %%
# List of columns to convert
ktes_columns_to_convert = [
    'Number_Students_Served_Full_Year', 
    'October_1_Enrollment',
    'PSSA_ELA_Percent_Students_Below_Basic_Grade_3',
    'PSSA_ELA_Percent_Students_Below_Basic_Grades_3_to_8',
    'PSSA_ELA_Percent_Students_Proficient_or_Advanced_Grade_3',
    'PSSA_ELA_Percent_Students_Proficient_or_Advanced_Grades_3_to_8',
    'PSSA_Math_Percent_Students_Below_Basic_Grade_3',
    'PSSA_Math_Percent_Students_Below_Basic_Grades_3_to_8',
    'PSSA_Math_Percent_Students_Proficient_or_Advanced_Grade_3',
    'PSSA_Math_Percent_Students_Proficient_or_Advanced_Grades_3_to_8',
    'PSSA_Science_Percent_Students_Below_Basic_Grades_4_to_8',
    'PSSA_Science_Percent_Students_Proficient_or_Advanced_Grades_4_to_8',
    'Percent_Metrics_Improving_All_Students',
    'Percent_Students_Attending_at_Least_90_Percent',
    'Number_Dropouts_Grades_7_to_12',
    'Percent_Students_Receiving_Zero_Out_of_School_Suspensions'
]

# Apply pd.to_numeric to convert strings to 'NaN'
ktes_metrics_df[ktes_columns_to_convert] = ktes_metrics_df[ktes_columns_to_convert].apply(lambda x: pd.to_numeric(x, errors='coerce'))

# Fill NaN values with a placeholder 0 before converting to integers
ktes_metrics_df.fillna({
    'Number_Students_Served_Full_Year': 0,
    'October_1_Enrollment': 0,
    'Number_Dropouts_Grades_7_to_12': 0,
}, inplace=True)

# Set the datatypes
ktes_metrics_df = ktes_metrics_df.astype({    
    'Number_Students_Served_Full_Year': 'int64', 
    'October_1_Enrollment': 'int64',
    'PSSA_ELA_Percent_Students_Below_Basic_Grade_3': 'float64',
    'PSSA_ELA_Percent_Students_Below_Basic_Grades_3_to_8': 'float64',
    'PSSA_ELA_Percent_Students_Proficient_or_Advanced_Grade_3': 'float64',
    'PSSA_ELA_Percent_Students_Proficient_or_Advanced_Grades_3_to_8': 'float64',
    'PSSA_Math_Percent_Students_Below_Basic_Grade_3': 'float64',
    'PSSA_Math_Percent_Students_Below_Basic_Grades_3_to_8': 'float64',
    'PSSA_Math_Percent_Students_Proficient_or_Advanced_Grade_3': 'float64',
    'PSSA_Math_Percent_Students_Proficient_or_Advanced_Grades_3_to_8': 'float64',
    'PSSA_Science_Percent_Students_Below_Basic_Grades_4_to_8': 'float64',
    'PSSA_Science_Percent_Students_Proficient_or_Advanced_Grades_4_to_8': 'float64',
    'Percent_Metrics_Improving_All_Students': 'float64',
    'Percent_Students_Attending_at_Least_90_Percent': 'float64',
    'Number_Dropouts_Grades_7_to_12': 'int64',
    'Percent_Students_Receiving_Zero_Out_of_School_Suspensions': 'float64'
})

# %%
ktes_metrics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154 entries, 0 to 153
# Data columns (total 21 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Year                                                                154 non-null    object
#  1   school_id                                                           154 non-null    int64
#  2   School_Name                                                         154 non-null    object
#  3   Report_Type                                                         154 non-null    object
#  4   Admission_Type                                                      154 non-null    object
#  5   Number_Students_Served_Full_Year                                    154 non-null    int64
#  6   October_1_Enrollment                                                154 non-null    int64
#  7   PSSA_ELA_Percent_Students_Below_Basic_Grade_3                       146 non-null    float64
#  8   PSSA_ELA_Percent_Students_Below_Basic_Grades_3_to_8                 154 non-null    float64
#  9   PSSA_ELA_Percent_Students_Proficient_or_Advanced_Grade_3            146 non-null    float64
#  10  PSSA_ELA_Percent_Students_Proficient_or_Advanced_Grades_3_to_8      154 non-null    float64
#  11  PSSA_Math_Percent_Students_Below_Basic_Grade_3                      147 non-null    float64
#  12  PSSA_Math_Percent_Students_Below_Basic_Grades_3_to_8                154 non-null    float64
#  13  PSSA_Math_Percent_Students_Proficient_or_Advanced_Grade_3           147 non-null    float64
#  14  PSSA_Math_Percent_Students_Proficient_or_Advanced_Grades_3_to_8     154 non-null    float64
#  15  PSSA_Science_Percent_Students_Below_Basic_Grades_4_to_8             153 non-null    float64
#  16  PSSA_Science_Percent_Students_Proficient_or_Advanced_Grades_4_to_8  153 non-null    float64
#  17  Percent_Metrics_Improving_All_Students                              154 non-null    float64
#  18  Percent_Students_Attending_at_Least_90_Percent                      152 non-null    float64
#  19  Number_Dropouts_Grades_7_to_12                                      154 non-null    int64
#  20  Percent_Students_Receiving_Zero_Out_of_School_Suspensions           152 non-null    float64
# dtypes: float64(13), int64(4), object(4)
# memory usage: 25.4+ KB

# %%
# Export to csv 
ktes_metrics_df.to_csv('Outputs_School_Metrics/ktoeight_school_metric_scores.csv', index=False)

# %%
elementary_school_metrics_df.head()
# Out:
#      accountability_year  school_id                 school_name  \
# 2340           2022-2023       1250  Joseph W. Catharine School
# 2344           2022-2023       1250  Joseph W. Catharine School
# 2348           2022-2023       1250  Joseph W. Catharine School
# 2349           2022-2023       1250  Joseph W. Catharine School
# 2463           2022-2023       1250  Joseph W. Catharine School
#
#             report_type                                             metric  \
# 2340  Elementary School                                     Admission Type
# 2344  Elementary School  % of Students Attending at Least 90% of Instru...
# 2348  Elementary School            # of Students Served Over the Full Year
# 2349  Elementary School                               October 1 Enrollment
# 2463  Elementary School  % of Students Receiving Zero Out-of-School Sus...
#
#       numerator  denominator metric_score score_previous    score_change  \
# 2340        NaN          NaN    Catchment   Neighborhood  Not Applicable
# 2344      298.0        447.0         66.7           56.1            10.6
# 2348        NaN          NaN          447            478             -31
# 2349        NaN          NaN          409            409               0
# 2463      447.0        447.0          100           99.4             0.6
#
#            tier
# 2340        NaN
# 2344  Improving
# 2348        NaN
# 2349        NaN
# 2463  Improving

# %%
# Pivot the elementary_school_metrics_df DataFrame to create one row for each school 
es_metrics_df = elementary_school_metrics_df.pivot_table(
    index = ['accountability_year', 'school_id', 'school_name', 'report_type'],
    columns = 'metric', 
    values = 'metric_score',
    aggfunc='first'
).reset_index()

es_metrics_df.head()
# Out:
# metric accountability_year  school_id                 school_name  \
# 0                2022-2023       1250  Joseph W. Catharine School
# 1                2022-2023       1380     Thomas G. Morton School
# 2                2022-2023       1390         Samuel Powel School
# 3                2022-2023       1400    John M. Patterson School
# 4                2022-2023       2320       Stephen Girard School
#
# metric        report_type # of Students Served Over the Full Year  \
# 0       Elementary School                                     447
# 1       Elementary School                                     424
# 2       Elementary School                                     317
# 3       Elementary School                                     420
# 4       Elementary School                                     336
#
# metric % of Students Attending at Least 90% of Instructional Days  \
# 0                                                    66.7
# 1                                                      59
# 2                                                    79.5
# 3                                                    57.6
# 4                                                    54.2
#
# metric % of Students Receiving Zero Out-of-School Suspensions  \
# 0                                                     100
# 1                                                    96.5
# 2                                                    99.7
# 3                                                    97.6
# 4                                                     100
#
# metric % of Teachers Attending at Least 90% of Instructional Days  \
# 0                                                      97
# 1                                                    85.7
# 2                                                    95.7
# 3                                                    79.2
# 4                                                     100
#
# metric % of Teachers Rated as Distinguished % of Teachers Rated as Proficient  \
# 0                                         0                              96.4
# 1                                         0                              84.6
# 2                                       5.9                              94.1
# 3                                         0                               100
# 4                                      22.2                              77.8
#
# metric  ... PSSA ELA: % of Students Proficient or Advanced, Grade 3  \
# 0       ...                                               18.9
# 1       ...                                               25.4
# 2       ...                                                 66
# 3       ...                                               20.3
# 4       ...                                               36.4
#
# metric PSSA ELA: % of Students Proficient or Advanced, Grades 3-8  \
# 0                                                      20
# 1                                                    24.6
# 2                                                    56.1
# 3                                                    22.8
# 4                                                    34.7
#
# metric PSSA Math: % of Students Below Basic, Grade 3  \
# 0                                               67.6
# 1                                               80.3
# 2                                               21.3
# 3                                               64.2
# 4                                               46.3
#
# metric PSSA Math: % of Students Below Basic, Grades 3-8  \
# 0                                                    64
# 1                                                  70.4
# 2                                                  22.5
# 3                                                  58.2
# 4                                                  46.4
#
# metric PSSA Math: % of Students Proficient or Advanced, Grade 3  \
# 0                                                    18.9
# 1                                                     6.6
# 2                                                    55.3
# 3                                                    11.9
# 4                                                    26.9
#
# metric PSSA Math: % of Students Proficient or Advanced, Grades 3-8  \
# 0                                                    14.8
# 1                                                     8.3
# 2                                                      51
# 3                                                    14.2
# 4                                                      28
#
# metric PSSA Science: % of Students Below Basic, Grades 4-8  \
# 0                                                    35.4
# 1                                                    29.8
# 2                                                    17.7
# 3                                                    20.9
# 4                                                    15.8
#
# metric PSSA Science: % of Students Proficient or Advanced, Grades 4-8  \
# 0                                                    33.9
# 1                                                    40.4
# 2                                                    62.8
# 3                                                    44.8
# 4                                                    52.6
#
# metric Percent of Metrics Improving,  All Students  \
# 0                                             61.5
# 1                                             92.3
# 2                                             76.9
# 3                                             38.5
# 4                                             92.3
#
# metric Year-to-Year Teacher Retention
# 0                                79.4
# 1                                85.3
# 2                                81.8
# 3                                  84
# 4                                91.3
#
# [5 rows x 24 columns]

# %%
# List the es_metrics_df columns
# es_metrics_df.columns

# %%
# Create a list with desireds column order
es_columns = [
    'accountability_year', 
    'school_id', 
    'school_name', 
    'report_type', 
    'Admission Type', 
    '# of Students Served Over the Full Year', 
    'October 1 Enrollment', 
    'PSSA ELA: % of Students Below Basic, Grade 3',
    'PSSA ELA: % of Students Below Basic, Grades 3-8',
    'PSSA ELA: % of Students Proficient or Advanced, Grade 3',
    'PSSA ELA: % of Students Proficient or Advanced, Grades 3-8',
    'PSSA Math: % of Students Below Basic, Grade 3',
    'PSSA Math: % of Students Below Basic, Grades 3-8',
    'PSSA Math: % of Students Proficient or Advanced, Grade 3',
    'PSSA Math: % of Students Proficient or Advanced, Grades 3-8',
    'PSSA Science: % of Students Below Basic, Grades 4-8',
    'PSSA Science: % of Students Proficient or Advanced, Grades 4-8',
    'Percent of Metrics Improving,  All Students', 
    '% of Students Attending at Least 90% of Instructional Days', 
    '% of Students Receiving Zero Out-of-School Suspensions'
]

# Reorder the DataFrame columns
es_metrics_df = es_metrics_df[es_columns]

# %%
# Rename the Columns with compatible formatting 
es_metrics_df = es_metrics_df.rename(columns={
    'accountability_year': 'Year', 
    'school_id': 'school_id', 
    'school_name': 'School_Name', 
    'report_type': 'Report_Type', 
    'Admission Type': 'Admission_Type', 
    '# of Students Served Over the Full Year': 'Number_Students_Served_Full_Year', 
    'October 1 Enrollment': 'October_1_Enrollment', 
    'PSSA ELA: % of Students Below Basic, Grade 3': 'PSSA_ELA_Percent_Students_Below_Basic_Grade_3',
    'PSSA ELA: % of Students Below Basic, Grades 3-8': 'PSSA_ELA_Percent_Students_Below_Basic_Grades_3_to_8',
    'PSSA ELA: % of Students Proficient or Advanced, Grade 3': 'PSSA_ELA_Percent_Students_Proficient_or_Advanced_Grade_3',
    'PSSA ELA: % of Students Proficient or Advanced, Grades 3-8': 'PSSA_ELA_Percent_Students_Proficient_or_Advanced_Grades_3_to_8',
    'PSSA Math: % of Students Below Basic, Grade 3': 'PSSA_Math_Percent_Students_Below_Basic_Grade_3',
    'PSSA Math: % of Students Below Basic, Grades 3-8': 'PSSA_Math_Percent_Students_Below_Basic_Grades_3_to_8',
    'PSSA Math: % of Students Proficient or Advanced, Grade 3': 'PSSA_Math_Percent_Students_Proficient_or_Advanced_Grade_3',
    'PSSA Math: % of Students Proficient or Advanced, Grades 3-8': 'PSSA_Math_Percent_Students_Proficient_or_Advanced_Grades_3_to_8',
    'PSSA Science: % of Students Below Basic, Grades 4-8': 'PSSA_Science_Percent_Students_Below_Basic_Grades_4_to_8',
    'PSSA Science: % of Students Proficient or Advanced, Grades 4-8': 'PSSA_Science_Percent_Students_Proficient_or_Advanced_Grades_4_to_8',
    'Percent of Metrics Improving,  All Students': 'Percent_Metrics_Improving_All_Students', 
    '% of Students Attending at Least 90% of Instructional Days': 'Percent_Students_Attending_at_Least_90_Percent', 
    '% of Students Receiving Zero Out-of-School Suspensions': 'Percent_Students_Receiving_Zero_Out_of_School_Suspensions'
})

es_metrics_df.head()
# Out:
# metric       Year  school_id                 School_Name        Report_Type  \
# 0       2022-2023       1250  Joseph W. Catharine School  Elementary School
# 1       2022-2023       1380     Thomas G. Morton School  Elementary School
# 2       2022-2023       1390         Samuel Powel School  Elementary School
# 3       2022-2023       1400    John M. Patterson School  Elementary School
# 4       2022-2023       2320       Stephen Girard School  Elementary School
#
# metric Admission_Type Number_Students_Served_Full_Year October_1_Enrollment  \
# 0           Catchment                              447                  409
# 1           Catchment                              424                  367
# 2           Catchment                              317                  295
# 3           Catchment                              420                  355
# 4           Catchment                              336                  291
#
# metric PSSA_ELA_Percent_Students_Below_Basic_Grade_3  \
# 0                                               35.1
# 1                                               35.6
# 2                                                8.5
# 3                                               39.1
# 4                                               25.8
#
# metric PSSA_ELA_Percent_Students_Below_Basic_Grades_3_to_8  \
# 0                                                    36.5
# 1                                                    38.9
# 2                                                    14.3
# 3                                                    39.8
# 4                                                    29.8
#
# metric PSSA_ELA_Percent_Students_Proficient_or_Advanced_Grade_3  \
# 0                                                    18.9
# 1                                                    25.4
# 2                                                      66
# 3                                                    20.3
# 4                                                    36.4
#
# metric PSSA_ELA_Percent_Students_Proficient_or_Advanced_Grades_3_to_8  \
# 0                                                      20
# 1                                                    24.6
# 2                                                    56.1
# 3                                                    22.8
# 4                                                    34.7
#
# metric PSSA_Math_Percent_Students_Below_Basic_Grade_3  \
# 0                                                67.6
# 1                                                80.3
# 2                                                21.3
# 3                                                64.2
# 4                                                46.3
#
# metric PSSA_Math_Percent_Students_Below_Basic_Grades_3_to_8  \
# 0                                                      64
# 1                                                    70.4
# 2                                                    22.5
# 3                                                    58.2
# 4                                                    46.4
#
# metric PSSA_Math_Percent_Students_Proficient_or_Advanced_Grade_3  \
# 0                                                    18.9
# 1                                                     6.6
# 2                                                    55.3
# 3                                                    11.9
# 4                                                    26.9
#
# metric PSSA_Math_Percent_Students_Proficient_or_Advanced_Grades_3_to_8  \
# 0                                                    14.8
# 1                                                     8.3
# 2                                                      51
# 3                                                    14.2
# 4                                                      28
#
# metric PSSA_Science_Percent_Students_Below_Basic_Grades_4_to_8  \
# 0                                                    35.4
# 1                                                    29.8
# 2                                                    17.7
# 3                                                    20.9
# 4                                                    15.8
#
# metric PSSA_Science_Percent_Students_Proficient_or_Advanced_Grades_4_to_8  \
# 0                                                    33.9
# 1                                                    40.4
# 2                                                    62.8
# 3                                                    44.8
# 4                                                    52.6
#
# metric Percent_Metrics_Improving_All_Students  \
# 0                                        61.5
# 1                                        92.3
# 2                                        76.9
# 3                                        38.5
# 4                                        92.3
#
# metric Percent_Students_Attending_at_Least_90_Percent  \
# 0                                                66.7
# 1                                                  59
# 2                                                79.5
# 3                                                57.6
# 4                                                54.2
#
# metric Percent_Students_Receiving_Zero_Out_of_School_Suspensions
# 0                                                     100
# 1                                                    96.5
# 2                                                    99.7
# 3                                                    97.6
# 4                                                     100

# %%
es_metrics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 20 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Year                                                                56 non-null     object
#  1   school_id                                                           56 non-null     int64
#  2   School_Name                                                         56 non-null     object
#  3   Report_Type                                                         56 non-null     object
#  4   Admission_Type                                                      56 non-null     object
#  5   Number_Students_Served_Full_Year                                    56 non-null     object
#  6   October_1_Enrollment                                                56 non-null     object
#  7   PSSA_ELA_Percent_Students_Below_Basic_Grade_3                       56 non-null     object
#  8   PSSA_ELA_Percent_Students_Below_Basic_Grades_3_to_8                 56 non-null     object
#  9   PSSA_ELA_Percent_Students_Proficient_or_Advanced_Grade_3            56 non-null     object
#  10  PSSA_ELA_Percent_Students_Proficient_or_Advanced_Grades_3_to_8      56 non-null     object
#  11  PSSA_Math_Percent_Students_Below_Basic_Grade_3                      56 non-null     object
#  12  PSSA_Math_Percent_Students_Below_Basic_Grades_3_to_8                56 non-null     object
#  13  PSSA_Math_Percent_Students_Proficient_or_Advanced_Grade_3           56 non-null     object
#  14  PSSA_Math_Percent_Students_Proficient_or_Advanced_Grades_3_to_8     56 non-null     object
#  15  PSSA_Science_Percent_Students_Below_Basic_Grades_4_to_8             56 non-null     object
#  16  PSSA_Science_Percent_Students_Proficient_or_Advanced_Grades_4_to_8  56 non-null     object
#  17  Percent_Metrics_Improving_All_Students                              56 non-null     object
#  18  Percent_Students_Attending_at_Least_90_Percent                      56 non-null     object
#  19  Percent_Students_Receiving_Zero_Out_of_School_Suspensions           56 non-null     object
# dtypes: int64(1), object(19)
# memory usage: 8.9+ KB

# %%
# List the es_metrics_df columns
# es_metrics_df.columns

# %%
# List of columns to convert
es_columns_to_convert = [
    'Number_Students_Served_Full_Year', 
    'October_1_Enrollment',
    'PSSA_ELA_Percent_Students_Below_Basic_Grade_3',
    'PSSA_ELA_Percent_Students_Below_Basic_Grades_3_to_8',
    'PSSA_ELA_Percent_Students_Proficient_or_Advanced_Grade_3',
    'PSSA_ELA_Percent_Students_Proficient_or_Advanced_Grades_3_to_8',
    'PSSA_Math_Percent_Students_Below_Basic_Grade_3',
    'PSSA_Math_Percent_Students_Below_Basic_Grades_3_to_8',
    'PSSA_Math_Percent_Students_Proficient_or_Advanced_Grade_3',
    'PSSA_Math_Percent_Students_Proficient_or_Advanced_Grades_3_to_8',
    'PSSA_Science_Percent_Students_Below_Basic_Grades_4_to_8',
    'PSSA_Science_Percent_Students_Proficient_or_Advanced_Grades_4_to_8',
    'Percent_Metrics_Improving_All_Students',
    'Percent_Students_Attending_at_Least_90_Percent',
    'Percent_Students_Receiving_Zero_Out_of_School_Suspensions'
]

# Apply pd.to_numeric to convert strings to 'NaN'
es_metrics_df[es_columns_to_convert] = es_metrics_df[es_columns_to_convert].apply(lambda x: pd.to_numeric(x, errors='coerce'))

# Set the datatypes
es_metrics_df = es_metrics_df.astype({    
    'Number_Students_Served_Full_Year': 'int64', 
    'October_1_Enrollment': 'int64',
    'PSSA_ELA_Percent_Students_Below_Basic_Grade_3': 'float64',
    'PSSA_ELA_Percent_Students_Below_Basic_Grades_3_to_8': 'float64',
    'PSSA_ELA_Percent_Students_Proficient_or_Advanced_Grade_3': 'float64',
    'PSSA_ELA_Percent_Students_Proficient_or_Advanced_Grades_3_to_8': 'float64',
    'PSSA_Math_Percent_Students_Below_Basic_Grade_3': 'float64',
    'PSSA_Math_Percent_Students_Below_Basic_Grades_3_to_8': 'float64',
    'PSSA_Math_Percent_Students_Proficient_or_Advanced_Grade_3': 'float64',
    'PSSA_Math_Percent_Students_Proficient_or_Advanced_Grades_3_to_8': 'float64',
    'PSSA_Science_Percent_Students_Below_Basic_Grades_4_to_8': 'float64',
    'PSSA_Science_Percent_Students_Proficient_or_Advanced_Grades_4_to_8': 'float64',
    'Percent_Metrics_Improving_All_Students': 'float64',
    'Percent_Students_Attending_at_Least_90_Percent': 'float64',
    'Percent_Students_Receiving_Zero_Out_of_School_Suspensions': 'float64'
})

# %%
es_metrics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 20 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Year                                                                56 non-null     object
#  1   school_id                                                           56 non-null     int64
#  2   School_Name                                                         56 non-null     object
#  3   Report_Type                                                         56 non-null     object
#  4   Admission_Type                                                      56 non-null     object
#  5   Number_Students_Served_Full_Year                                    56 non-null     int64
#  6   October_1_Enrollment                                                56 non-null     int64
#  7   PSSA_ELA_Percent_Students_Below_Basic_Grade_3                       54 non-null     float64
#  8   PSSA_ELA_Percent_Students_Below_Basic_Grades_3_to_8                 54 non-null     float64
#  9   PSSA_ELA_Percent_Students_Proficient_or_Advanced_Grade_3            54 non-null     float64
#  10  PSSA_ELA_Percent_Students_Proficient_or_Advanced_Grades_3_to_8      54 non-null     float64
#  11  PSSA_Math_Percent_Students_Below_Basic_Grade_3                      54 non-null     float64
#  12  PSSA_Math_Percent_Students_Below_Basic_Grades_3_to_8                54 non-null     float64
#  13  PSSA_Math_Percent_Students_Proficient_or_Advanced_Grade_3           54 non-null     float64
#  14  PSSA_Math_Percent_Students_Proficient_or_Advanced_Grades_3_to_8     54 non-null     float64
#  15  PSSA_Science_Percent_Students_Below_Basic_Grades_4_to_8             54 non-null     float64
#  16  PSSA_Science_Percent_Students_Proficient_or_Advanced_Grades_4_to_8  54 non-null     float64
#  17  Percent_Metrics_Improving_All_Students                              54 non-null     float64
#  18  Percent_Students_Attending_at_Least_90_Percent                      56 non-null     float64
#  19  Percent_Students_Receiving_Zero_Out_of_School_Suspensions           56 non-null     float64
# dtypes: float64(13), int64(3), object(4)
# memory usage: 8.9+ KB

# %%
# Export to csv 
es_metrics_df.to_csv('Outputs_School_Metrics/elementary_school_metric_scores.csv', index=False)
